# %%
import sys;sys.path.append('../')
import os

from rich import print

openai_key=open('../openai.key').read().strip()
os.environ['OPENAI_API_KEY'] = openai_key

# %%
from multi_agent_llm import OpenAILLM
from multi_agent_llm import CLU,KMU

llm = OpenAILLM(model_name="gpt-4o-mini")

# %%
# kmu = KMU(
#     llm,
#     main_goal="Maintain a knowledge base about machine learning",
#     storage_goal="Store concise and relevant information",
#     retrieval_goal="Retrieve accurate and up-to-date information",
#     name="ML_Knowledge",
# )

# # Save some knowledge
# id1 = kmu.save("Neural networks are a type of machine learning model inspired by the human brain.")
# id2 = kmu.save("Gradient descent is an optimization algorithm used to minimize the loss function in machine learning models.")

# # Retrieve knowledge
# results = kmu.retrieve("How do neural networks work?")
# print("Retrieved:", results)

# # Prune knowledge
# new_ids = kmu.prune("The information about neural networks is outdated.", [id1])
# print("New IDs after pruning:", new_ids)

# %%
# clu = CLU(
#     llm,
#     main_goal="Provide accurate and helpful information across various domains",
#     name="GeneralCLU"
# )

# # Manually add some knowledge to the KMUs
# clu.save_general_knowledge(
#     "Neural networks are a type of machine learning model inspired by the human brain."
# )
# clu.save_general_knowledge(
#     "Climate change is causing global temperatures to rise, leading to various environmental impacts."
# )
# clu.save_prompt_knowledge(
#     "When explaining complex topics, start with a simple analogy before providing technical details."
# )
# clu.save_prompt_knowledge(
#     "For problem-solving tasks, guide the reasoning process step-by-step, encouraging thorough analysis."
# )

# %%
# Perform reasoning
from pydantic import BaseModel, Field
class OperationalAgentOutput(BaseModel):
    response: str = Field(
        ..., description="The response generated by the Operational Agent"
    )

# %%
# # Perform training
# query = "Explain the potential impacts of climate change on marine ecosystems"
# expected_output = "Climate change affects marine ecosystems through ocean warming, acidification, and sea level rise, leading to habitat loss and species migration."
# training_result = clu.train(
#     query, expected_output, OperationalAgentOutput, verbose=True
# )

# %%
# Perform reasoning
from pydantic import BaseModel, Field
class OperationalAgentOutput(BaseModel):
    explanation: str = Field(
        ..., description="Explanation of logic of transformation"
    )
    answer: str = Field(...,description="Final answer")

# %%
clu = CLU(
    llm,
    main_goal="Try out various techniques and Find the hidden rule and learn the transformation logic of the cryptographic puzzle",
    name="PuzzleSolverCLU3"
)

# Perform training
query = """Given:
"Neural networks transform data efficiently" → "eeraf"
"Artificial intelligence automates decisions" → "rnue" 
Query:
What is "Gradient descent optimizes loss functions" → ?"""

expected_output = "repou"

training_result = clu.train(query, expected_output, OperationalAgentOutput, verbose=True)
# Out:
# Starting Training Process
# Starting Reasoning Process
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                              General KMU Retrieval                                              │
# │  Input:   Given:                                                                                                │
# │           "Neural networks transform data efficiently" → "eeraf"                                                │
# │           "Artificial intelligence automates decisions" → "rnue"                                                │
# │           Query:                                                                                                │
# │           What is "Gradient descent optimizes loss functions" → ?                                               │
# │  Output:  ['1. **Pattern Analysis**: Establish a systematic approach to compare outputs from different phrases  │
# │           regularly. Focus on identifying unique patterns and rules in the letter selection process to enhance  │
# │           understanding and recognition of various transformation logics.', '1. **Identify Non-Linear           │
# │           Patterns**: Acknowledge that letter selection may involve non-sequential indices, lateral shifts, or  │
# │           transformations that deviate from direct extraction. This understanding is critical for decoding      │
# │           cryptographic puzzles.', '**Abstract Knowledge**: Utilize diverse methodologies in cryptographic      │
# │           analysis, focusing on contextual relevance, frequency, and qualitative metrics alongside basic        │
# │           positional identification for enhanced letter extraction. \n\n**Strategy**: Implement a               │
# │           multi-faceted letter extraction technique that goes beyond classic approaches to unveil deeper        │
# │           patterns and rules in cryptographic puzzles.', 'Develop an **Extraction Framework** to categorize     │
# │           characters based on phrase structure, enhancing the identification of selection rules for             │
# │           cryptographic patterns.', '1. **Transformative Logic Overview**: Document the general principles      │
# │           that underlie cryptographic transformations. \n2. **Methodological Consistency**: Emphasize the       │
# │           importance of applying a consistent methodology across transformations to maintain reliability. \n3.  │
# │           **Diverse Transformation Techniques**: Include examples of various transformation techniques such as  │
# │           substitution, transposition, and encoding, highlighting when to use each. \n4. **Analytical           │
# │           Insights**: Provide insights on how to analyze the outcome of transformations to identify underlying  │
# │           patterns or rules. \n5. **Future Application**: Encourage leveraging this summary as a foundational   │
# │           tool when tackling new cryptographic puzzles.']                                                       │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                              Prompt KMU Retrieval                                               │
# │  Input:   Given:                                                                                                │
# │           "Neural networks transform data efficiently" → "eeraf"                                                │
# │           "Artificial intelligence automates decisions" → "rnue"                                                │
# │           Query:                                                                                                │
# │           What is "Gradient descent optimizes loss functions" → ?                                               │
# │  Output:  ['Identify patterns that might include letter omission or non-conventional sequences in               │
# │           transformations.', 'Identify coding patterns in phrases for cryptographic puzzles. Focus on letter    │
# │           manipulation and sequencing to create coded outputs. Apply these strategies in various problems.',    │
# │           'Utilize a cycle of iterative testing and feedback evaluation to enhance prompt strategies for        │
# │           letter extraction and transformation logic in cryptographic tasks.', 'Emphasize the importance of a   │
# │           holistic approach in character extraction. Avoid linear assumptions; instead, analyze the             │
# │           interrelationships of letters and their positional context within words to develop more effective     │
# │           prompts.', "Identify characters for prompt generation: Extract 'g', 'd', 'o', 'l' from specific       │
# │           words. Consider advanced manipulations like substitutions or transformations to enhance prompt        │
# │           effectiveness in reasoning."]                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                Meta-Prompt Agent                                                │
# │  Input:   [{'role': 'system', 'content': 'You are the Meta-Prompt Agent in the Composite Learning Unit.\n       │
# │           Main Goal: Refine strategies for generating effective prompts that can guide reasoning across         │
# │           various types of tasks.Extract relevant information needed to construct high-quality prompts based    │
# │           on the feedback from answering specific task-related query with a given old prompt. - Main goal:      │
# │           {main_goal}\n        Your task is to generate a detailed, task-specific prompt for the Operational    │
# │           Agent based on the given task and retrieved prompt knowledge.\n        This prompt should guide the   │
# │           Operational Agent in effectively using the general knowledge to complete the task.'}, {'role':        │
# │           'user', 'content': 'Task: Given:\n"Neural networks transform data efficiently" →                      │
# │           "eeraf"\n"Artificial intelligence automates decisions" → "rnue" \nQuery:\nWhat is "Gradient descent   │
# │           optimizes loss functions" → ?\nPrompt Knowledge: [\'Identify patterns that might include letter       │
# │           omission or non-conventional sequences in transformations.\', \'Identify coding patterns in phrases   │
# │           for cryptographic puzzles. Focus on letter manipulation and sequencing to create coded outputs.       │
# │           Apply these strategies in various problems.\', \'Utilize a cycle of iterative testing and feedback    │
# │           evaluation to enhance prompt strategies for letter extraction and transformation logic in             │
# │           cryptographic tasks.\', \'Emphasize the importance of a holistic approach in character extraction.    │
# │           Avoid linear assumptions; instead, analyze the interrelationships of letters and their positional     │
# │           context within words to develop more effective prompts.\', "Identify characters for prompt            │
# │           generation: Extract \'g\', \'d\', \'o\', \'l\' from specific words. Consider advanced manipulations   │
# │           like substitutions or transformations to enhance prompt effectiveness in reasoning."]\nGenerate a     │
# │           detailed task-specific prompt:'}]                                                                     │
# │  Output:  Given the sentence "Gradient descent optimizes loss functions", apply the strategies of letter        │
# │           manipulation and sequencing identified from the previous transformations. Pay close attention to      │
# │           patterns of letter omission or rearrangement as observed in previous examples.                        │
# │                                                                                                                 │
# │           1. Begin by analyzing the individual words for key letters that may be crucial to the transformation  │
# │           process.                                                                                              │
# │           2. Focus on coding patterns: consider whether letters need to be omitted, reshuffled, or              │
# │           substituted.                                                                                          │
# │           3. Maintain awareness of each letter's position and any potential relationships to other letters,     │
# │           ensuring you do not adhere strictly to linear extraction methods.                                     │
# │           4. Use feedback from previous transformations to inform your choices: for example, observe how the    │
# │           outputs were created in earlier tasks by identifying letters such as 'g', 'd', 'o', 'l', and think    │
# │           about how similar letters might be extracted or transformed from this new sentence.                   │
# │                                                                                                                 │
# │           Finally, present your resulting coded output for the phrase "Gradient descent optimizes loss          │
# │           functions" based on your findings and reasoning.                                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                Operational Agent                                                │
# │  Input:   [{'role': 'system', 'content': 'You are the Operational Agent in the Composite Learning Unit.\n       │
# │           Main Goal: Try out various techniques and Find the hidden rule and learn the transformation logic of  │
# │           the cryptographic puzzle\n        Your task is to process the given task using the provided general   │
# │           knowledge and following the detailed task-specific prompt.\n        Before answering, first think     │
# │           step by step and explain the reasoning behind the answer and how the which parts of the general       │
# │           knowledge and prompt knowledge were used to arrive at the answer. Give detailed reasoning and         │
# │           explanation.\n        '}, {'role': 'user', 'content': 'Task: Given:\n"Neural networks transform data  │
# │           efficiently" → "eeraf"\n"Artificial intelligence automates decisions" → "rnue" \nQuery:\nWhat is      │
# │           "Gradient descent optimizes loss functions" → ?\nGeneral Knowledge: [\'1. **Pattern Analysis**:       │
# │           Establish a systematic approach to compare outputs from different phrases regularly. Focus on         │
# │           identifying unique patterns and rules in the letter selection process to enhance understanding and    │
# │           recognition of various transformation logics.\', \'1. **Identify Non-Linear Patterns**: Acknowledge   │
# │           that letter selection may involve non-sequential indices, lateral shifts, or transformations that     │
# │           deviate from direct extraction. This understanding is critical for decoding cryptographic             │
# │           puzzles.\', \'**Abstract Knowledge**: Utilize diverse methodologies in cryptographic analysis,        │
# │           focusing on contextual relevance, frequency, and qualitative metrics alongside basic positional       │
# │           identification for enhanced letter extraction. \\n\\n**Strategy**: Implement a multi-faceted letter   │
# │           extraction technique that goes beyond classic approaches to unveil deeper patterns and rules in       │
# │           cryptographic puzzles.\', \'Develop an **Extraction Framework** to categorize characters based on     │
# │           phrase structure, enhancing the identification of selection rules for cryptographic patterns.\',      │
# │           \'1. **Transformative Logic Overview**: Document the general principles that underlie cryptographic   │
# │           transformations. \\n2. **Methodological Consistency**: Emphasize the importance of applying a         │
# │           consistent methodology across transformations to maintain reliability. \\n3. **Diverse                │
# │           Transformation Techniques**: Include examples of various transformation techniques such as            │
# │           substitution, transposition, and encoding, highlighting when to use each. \\n4. **Analytical          │
# │           Insights**: Provide insights on how to analyze the outcome of transformations to identify underlying  │
# │           patterns or rules. \\n5. **Future Application**: Encourage leveraging this summary as a foundational  │
# │           tool when tackling new cryptographic puzzles.\']\nDetailed Task-Specific Prompt: Given the sentence   │
# │           "Gradient descent optimizes loss functions", apply the strategies of letter manipulation and          │
# │           sequencing identified from the previous transformations. Pay close attention to patterns of letter    │
# │           omission or rearrangement as observed in previous examples. \n\n1. Begin by analyzing the individual  │
# │           words for key letters that may be crucial to the transformation process.\n2. Focus on coding          │
# │           patterns: consider whether letters need to be omitted, reshuffled, or substituted. \n3. Maintain      │
# │           awareness of each letter\'s position and any potential relationships to other letters, ensuring you   │
# │           do not adhere strictly to linear extraction methods.\n4. Use feedback from previous transformations   │
# │           to inform your choices: for example, observe how the outputs were created in earlier tasks by         │
# │           identifying letters such as \'g\', \'d\', \'o\', \'l\', and think about how similar letters might be  │
# │           extracted or transformed from this new sentence.\n\nFinally, present your resulting coded output for  │
# │           the phrase "Gradient descent optimizes loss functions" based on your findings and                     │
# │           reasoning.\nExecute the task:'}]                                                                      │
# │  Output:  explanation='To determine the transformation of the phrase "Gradient descent optimizes loss           │
# │           functions", we first analyze the phrases provided in the examples for their output patterns. Looking  │
# │           at the first example, "Neural networks transform data efficiently" yielding "eeraf", the              │
# │           transformation seems to involve selective omission or manipulation of letters: \'e\', \'e\', \'r\',   │
# │           \'a\', and \'f\'. Similarly, for the second phrase, "Artificial intelligence automates decisions"     │
# │           resulting in "rnue", we observe that specific letters are extracted also based on their sequences or  │
# │           occurrences within the phrase. Our provided phrase consists of 5 words and involves keywords like     │
# │           \'descent\', \'optimizes\', and \'loss\'.  \n\nThrough analyzing the provided phrases, I note a       │
# │           tendency for letters that contribute to conveying conceptual weight or importance are being selected  │
# │           over others. \n\nUsing this understanding, I identify relevant letters by examining the structure     │
# │           and meaning. From "Gradient descent optimizes loss functions", I select the letters \'g\', \'d\',     │
# │           \'o\', \'l\', and ‘s’. These letters appear key for retaining the essence of optimization and loss    │
# │           while reflecting a non-linear extraction process. \n\nThe word structure leads me to focus on         │
# │           keeping letters that directly relate to the primary concepts of gradient descent and loss. Following  │
# │           previous patterns, I will select alternating letters and maintain a balance, resembling the previous  │
# │           transformations. \n\nConclusively, the resulting coded output, simplified and hashed based on         │
# │           patterns observed from prior examples, is "gdof". \nThis output embraces the essence of the original  │
# │           phrase while staying aligned with the demonstrated transformations.'                                  │
# │           answer=OperationalAgentOutput(explanation='To determine the transformation of the phrase "Gradient    │
# │           descent optimizes loss functions", we first analyze the phrases provided in the examples for their    │
# │           output patterns. Looking at the first example, "Neural networks transform data efficiently" yielding  │
# │           "eeraf", the transformation seems to involve selective omission or manipulation of letters: \'e\',    │
# │           \'e\', \'r\', \'a\', and \'f\'. Similarly, for the second phrase, "Artificial intelligence automates  │
# │           decisions" resulting in "rnue", we observe that specific letters are extracted also based on their    │
# │           sequences or occurrences within the phrase. Our provided phrase consists of 5 words and involves      │
# │           keywords like \'descent\', \'optimizes\', and \'loss\'.  \n\nThrough analyzing the provided phrases,  │
# │           I note a tendency for letters that contribute to conveying conceptual weight or importance are being  │
# │           selected over others. \n\nUsing this understanding, I identify relevant letters by examining the      │
# │           structure and meaning. From "Gradient descent optimizes loss functions", I select the letters \'g\',  │
# │           \'d\', \'o\', \'l\', and ‘s’. These letters appear key for retaining the essence of optimization and  │
# │           loss while reflecting a non-linear extraction process. \n\nThe word structure leads me to focus on    │
# │           keeping letters that directly relate to the primary concepts of gradient descent and loss. Following  │
# │           previous patterns, I will select alternating letters and maintain a balance, resembling the previous  │
# │           transformations. \n\nConclusively, the resulting coded output, simplified and hashed based on         │
# │           patterns observed from prior examples, is "gdof". \nThis output embraces the essence of the original  │
# │           phrase while staying aligned with the demonstrated transformations.', answer='gdof')                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Reasoning Process Completed
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                Comparison Agent                                                 │
# │  Input:   [{'role': 'system', 'content': 'You are the Comparison Agent in the Composite Learning Unit.\n        │
# │           Main Goal: Try out various techniques and Find the hidden rule and learn the transformation logic of  │
# │           the cryptographic puzzle\n        Your task is to compare the generated output with the expected      │
# │           output, considering the query and main goal.\n        Determine if they are equivalent, either        │
# │           verbatim or semantically, based on the context of the task.\n        \n        - Determine if the     │
# │           response matches the expected output exactly\n        - If it does not match exactly see if it        │
# │           matches in meaning and intent clearly and unambiguously.\n        - Provide an explanation of your    │
# │           comparison, highlighting similarities and differences\n        - Return a boolean indicating whether  │
# │           the response is correct and an explanation\n        - Do not speculate what might be the reason for   │
# │           the difference, focus on the comparison itself.\n        '}, {'role': 'user', 'content': 'Query:      │
# │           Given:\n"Neural networks transform data efficiently" → "eeraf"\n"Artificial intelligence automates    │
# │           decisions" → "rnue" \nQuery:\nWhat is "Gradient descent optimizes loss functions" → ?\n               │
# │           Generated Output: explanation=\'To determine the transformation of the phrase "Gradient descent       │
# │           optimizes loss functions", we first analyze the phrases provided in the examples for their output     │
# │           patterns. Looking at the first example, "Neural networks transform data efficiently" yielding         │
# │           "eeraf", the transformation seems to involve selective omission or manipulation of letters:           │
# │           \\\'e\\\', \\\'e\\\', \\\'r\\\', \\\'a\\\', and \\\'f\\\'. Similarly, for the second phrase,          │
# │           "Artificial intelligence automates decisions" resulting in "rnue", we observe that specific letters   │
# │           are extracted also based on their sequences or occurrences within the phrase. Our provided phrase     │
# │           consists of 5 words and involves keywords like \\\'descent\\\', \\\'optimizes\\\', and \\\'loss\\\'.  │
# │           \\n\\nThrough analyzing the provided phrases, I note a tendency for letters that contribute to        │
# │           conveying conceptual weight or importance are being selected over others. \\n\\nUsing this            │
# │           understanding, I identify relevant letters by examining the structure and meaning. From "Gradient     │
# │           descent optimizes loss functions", I select the letters \\\'g\\\', \\\'d\\\', \\\'o\\\', \\\'l\\\',   │
# │           and ‘s’. These letters appear key for retaining the essence of optimization and loss while            │
# │           reflecting a non-linear extraction process. \\n\\nThe word structure leads me to focus on keeping     │
# │           letters that directly relate to the primary concepts of gradient descent and loss. Following          │
# │           previous patterns, I will select alternating letters and maintain a balance, resembling the previous  │
# │           transformations. \\n\\nConclusively, the resulting coded output, simplified and hashed based on       │
# │           patterns observed from prior examples, is "gdof". \\nThis output embraces the essence of the          │
# │           original phrase while staying aligned with the demonstrated transformations.\'                        │
# │           answer=OperationalAgentOutput(explanation=\'To determine the transformation of the phrase "Gradient   │
# │           descent optimizes loss functions", we first analyze the phrases provided in the examples for their    │
# │           output patterns. Looking at the first example, "Neural networks transform data efficiently" yielding  │
# │           "eeraf", the transformation seems to involve selective omission or manipulation of letters:           │
# │           \\\'e\\\', \\\'e\\\', \\\'r\\\', \\\'a\\\', and \\\'f\\\'. Similarly, for the second phrase,          │
# │           "Artificial intelligence automates decisions" resulting in "rnue", we observe that specific letters   │
# │           are extracted also based on their sequences or occurrences within the phrase. Our provided phrase     │
# │           consists of 5 words and involves keywords like \\\'descent\\\', \\\'optimizes\\\', and \\\'loss\\\'.  │
# │           \\n\\nThrough analyzing the provided phrases, I note a tendency for letters that contribute to        │
# │           conveying conceptual weight or importance are being selected over others. \\n\\nUsing this            │
# │           understanding, I identify relevant letters by examining the structure and meaning. From "Gradient     │
# │           descent optimizes loss functions", I select the letters \\\'g\\\', \\\'d\\\', \\\'o\\\', \\\'l\\\',   │
# │           and ‘s’. These letters appear key for retaining the essence of optimization and loss while            │
# │           reflecting a non-linear extraction process. \\n\\nThe word structure leads me to focus on keeping     │
# │           letters that directly relate to the primary concepts of gradient descent and loss. Following          │
# │           previous patterns, I will select alternating letters and maintain a balance, resembling the previous  │
# │           transformations. \\n\\nConclusively, the resulting coded output, simplified and hashed based on       │
# │           patterns observed from prior examples, is "gdof". \\nThis output embraces the essence of the          │
# │           original phrase while staying aligned with the demonstrated transformations.\', answer=\'gdof\')\n    │
# │           Expected Output: repou\n        Are these outputs equivalent? Provide a boolean result and a          │
# │           detailed explanation.\n        '}]                                                                    │
# │  Output:  Equivalent: False                                                                                     │
# │           Explanation: The generated output 'gdof' differs from the expected output 'repou' both in terms of    │
# │           the letters included and their order. In the comparison, I examined the transformation logic applied  │
# │           in the previous examples but arrived at a different selection of letters. The output 'gdof' focuses   │
# │           on letters associated with key terms from the original phrase like 'gradient' and 'loss', while the   │
# │           expected output 'repou' appears to derive from a different selection of letters that do not align     │
# │           with the observed patterns. Overall, while both outputs aim to encapsulate the essence of the         │
# │           original phrase, they are not equivalent as they do not match in terms of the letters or their        │
# │           arrangement.                                                                                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                             Negative Feedback Agent                                             │
# │  Input:   [{'role': 'system', 'content': "You are the Negative Feedback Agent in the Composite Learning         │
# │           Unit.\n            Main Goal: Try out various techniques and Find the hidden rule and learn the       │
# │           transformation logic of the cryptographic puzzle\n            Your task is to provide specific,       │
# │           targeted feedback to correct and improve the CLU's performance.\n            Focus on two aspects:\n  │
# │           1. Identify gaps or inaccuracies in the general knowledge base that led to the incorrect outcome.\n   │
# │           2. Analyze how the knowledge may have misguided the reasoning process.\n            3.  Evaluate why  │
# │           the response does not match the expected output\n            4.  Identify gaps in knowledge or        │
# │           reasoning that led to the incorrect answer\n            5.  Suggest specific changes and              │
# │           improvements to the knowledge base\n            6.  Provide strategies to avoid similar mistakes in   │
# │           the future\n            7. Identify key elements in the reasoning that led to the incorrect answer\n  │
# │           Provide constructive feedback that addresses these issues and suggests concrete improvements and      │
# │           changes."}, {'role': 'user', 'content': 'Query: Given:\n"Neural networks transform data efficiently"  │
# │           → "eeraf"\n"Artificial intelligence automates decisions" → "rnue" \nQuery:\nWhat is "Gradient         │
# │           descent optimizes loss functions" → ?\n        Generated Output: explanation=\'To determine the       │
# │           transformation of the phrase "Gradient descent optimizes loss functions", we first analyze the        │
# │           phrases provided in the examples for their output patterns. Looking at the first example, "Neural     │
# │           networks transform data efficiently" yielding "eeraf", the transformation seems to involve selective  │
# │           omission or manipulation of letters: \\\'e\\\', \\\'e\\\', \\\'r\\\', \\\'a\\\', and \\\'f\\\'.       │
# │           Similarly, for the second phrase, "Artificial intelligence automates decisions" resulting in "rnue",  │
# │           we observe that specific letters are extracted also based on their sequences or occurrences within    │
# │           the phrase. Our provided phrase consists of 5 words and involves keywords like \\\'descent\\\',       │
# │           \\\'optimizes\\\', and \\\'loss\\\'.  \\n\\nThrough analyzing the provided phrases, I note a          │
# │           tendency for letters that contribute to conveying conceptual weight or importance are being selected  │
# │           over others. \\n\\nUsing this understanding, I identify relevant letters by examining the structure   │
# │           and meaning. From "Gradient descent optimizes loss functions", I select the letters \\\'g\\\',        │
# │           \\\'d\\\', \\\'o\\\', \\\'l\\\', and ‘s’. These letters appear key for retaining the essence of       │
# │           optimization and loss while reflecting a non-linear extraction process. \\n\\nThe word structure      │
# │           leads me to focus on keeping letters that directly relate to the primary concepts of gradient         │
# │           descent and loss. Following previous patterns, I will select alternating letters and maintain a       │
# │           balance, resembling the previous transformations. \\n\\nConclusively, the resulting coded output,     │
# │           simplified and hashed based on patterns observed from prior examples, is "gdof". \\nThis output       │
# │           embraces the essence of the original phrase while staying aligned with the demonstrated               │
# │           transformations.\' answer=OperationalAgentOutput(explanation=\'To determine the transformation of     │
# │           the phrase "Gradient descent optimizes loss functions", we first analyze the phrases provided in the  │
# │           examples for their output patterns. Looking at the first example, "Neural networks transform data     │
# │           efficiently" yielding "eeraf", the transformation seems to involve selective omission or              │
# │           manipulation of letters: \\\'e\\\', \\\'e\\\', \\\'r\\\', \\\'a\\\', and \\\'f\\\'. Similarly, for    │
# │           the second phrase, "Artificial intelligence automates decisions" resulting in "rnue", we observe      │
# │           that specific letters are extracted also based on their sequences or occurrences within the phrase.   │
# │           Our provided phrase consists of 5 words and involves keywords like \\\'descent\\\',                   │
# │           \\\'optimizes\\\', and \\\'loss\\\'.  \\n\\nThrough analyzing the provided phrases, I note a          │
# │           tendency for letters that contribute to conveying conceptual weight or importance are being selected  │
# │           over others. \\n\\nUsing this understanding, I identify relevant letters by examining the structure   │
# │           and meaning. From "Gradient descent optimizes loss functions", I select the letters \\\'g\\\',        │
# │           \\\'d\\\', \\\'o\\\', \\\'l\\\', and ‘s’. These letters appear key for retaining the essence of       │
# │           optimization and loss while reflecting a non-linear extraction process. \\n\\nThe word structure      │
# │           leads me to focus on keeping letters that directly relate to the primary concepts of gradient         │
# │           descent and loss. Following previous patterns, I will select alternating letters and maintain a       │
# │           balance, resembling the previous transformations. \\n\\nConclusively, the resulting coded output,     │
# │           simplified and hashed based on patterns observed from prior examples, is "gdof". \\nThis output       │
# │           embraces the essence of the original phrase while staying aligned with the demonstrated               │
# │           transformations.\', answer=\'gdof\')\n        Expected Output: repou\n        Comparison              │
# │           Explanation: The generated output \'gdof\' differs from the expected output \'repou\' both in terms   │
# │           of the letters included and their order. In the comparison, I examined the transformation logic       │
# │           applied in the previous examples but arrived at a different selection of letters. The output          │
# │           \'gdof\' focuses on letters associated with key terms from the original phrase like \'gradient\' and  │
# │           \'loss\', while the expected output \'repou\' appears to derive from a different selection of         │
# │           letters that do not align with the observed patterns. Overall, while both outputs aim to encapsulate  │
# │           the essence of the original phrase, they are not equivalent as they do not match in terms of the      │
# │           letters or their arrangement.\n        General Knowledge Used: [\'1. **Pattern Analysis**: Establish  │
# │           a systematic approach to compare outputs from different phrases regularly. Focus on identifying       │
# │           unique patterns and rules in the letter selection process to enhance understanding and recognition    │
# │           of various transformation logics.\', \'1. **Identify Non-Linear Patterns**: Acknowledge that letter   │
# │           selection may involve non-sequential indices, lateral shifts, or transformations that deviate from    │
# │           direct extraction. This understanding is critical for decoding cryptographic puzzles.\',              │
# │           \'**Abstract Knowledge**: Utilize diverse methodologies in cryptographic analysis, focusing on        │
# │           contextual relevance, frequency, and qualitative metrics alongside basic positional identification    │
# │           for enhanced letter extraction. \\n\\n**Strategy**: Implement a multi-faceted letter extraction       │
# │           technique that goes beyond classic approaches to unveil deeper patterns and rules in cryptographic    │
# │           puzzles.\', \'Develop an **Extraction Framework** to categorize characters based on phrase            │
# │           structure, enhancing the identification of selection rules for cryptographic patterns.\', \'1.        │
# │           **Transformative Logic Overview**: Document the general principles that underlie cryptographic        │
# │           transformations. \\n2. **Methodological Consistency**: Emphasize the importance of applying a         │
# │           consistent methodology across transformations to maintain reliability. \\n3. **Diverse                │
# │           Transformation Techniques**: Include examples of various transformation techniques such as            │
# │           substitution, transposition, and encoding, highlighting when to use each. \\n4. **Analytical          │
# │           Insights**: Provide insights on how to analyze the outcome of transformations to identify underlying  │
# │           patterns or rules. \\n5. **Future Application**: Encourage leveraging this summary as a foundational  │
# │           tool when tackling new cryptographic puzzles.\']\n        Prompt Knowledge Used: [\'Identify          │
# │           patterns that might include letter omission or non-conventional sequences in transformations.\',      │
# │           \'Identify coding patterns in phrases for cryptographic puzzles. Focus on letter manipulation and     │
# │           sequencing to create coded outputs. Apply these strategies in various problems.\', \'Utilize a cycle  │
# │           of iterative testing and feedback evaluation to enhance prompt strategies for letter extraction and   │
# │           transformation logic in cryptographic tasks.\', \'Emphasize the importance of a holistic approach in  │
# │           character extraction. Avoid linear assumptions; instead, analyze the interrelationships of letters    │
# │           and their positional context within words to develop more effective prompts.\', "Identify characters  │
# │           for prompt generation: Extract \'g\', \'d\', \'o\', \'l\' from specific words. Consider advanced      │
# │           manipulations like substitutions or transformations to enhance prompt effectiveness in                │
# │           reasoning."]\n        Provide detailed, through and targeted feedback for improving general           │
# │           knowledge and prompt knowledge:'}]                                                                    │
# │  Output:  General Knowledge Feedback: 1. **Pattern Recognition Improvement**: The analysis of the pattern       │
# │           among letter transformations could be more nuanced. The general knowledge should include a thorough   │
# │           examination of the original output letters and their positions relative to their source phrases.      │
# │           Specifically, understanding the significance of the first letter of each word will help clarify why   │
# │           certain letters were chosen.                                                                          │
# │                                                                                                                 │
# │           2. **Additional Examples**: Incorporate more diverse case studies that illustrate various             │
# │           transformation rules and outcomes. Collect a database of examples illustrating different patterns     │
# │           can help build a robust framework for understanding the transformation logic.                         │
# │           Prompt Knowledge Feedback: 1. **Clarified Extraction Logic**: The focus should not only be on         │
# │           significant keywords but also on the order of letters. Encourage a prompt strategy that tracks the    │
# │           exact sequence and positional value of letters in the original phrase, aligning with the expected     │
# │           output.                                                                                               │
# │                                                                                                                 │
# │           2. **Iterative Feedback System**: Establish a clearer process for reaffirming the outputs by testing  │
# │           against known transformations, allowing for iterative learning when encountering new phrases. This    │
# │           could prevent deviations from established patterns in future queries.                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                        Prompt Knowledge Alignment Agent                                         │
# │  Input:   [{'role': 'system', 'content': 'You are the Knowledge Alignment Agent for prompt knowledge in the     │
# │           Composite Learning Unit.\n        Main Goal: Try out various techniques and Find the hidden rule and  │
# │           learn the transformation logic of the cryptographic puzzle\n        Your task is to process the       │
# │           feedback and existing knowledge to generate a comprehensive list of knowledge entries that will       │
# │           replace the current knowledge base.\n        This list should include:\n        1. Modified versions  │
# │           of existing knowledge entries that address the feedback.\n        2. New knowledge entries that fill  │
# │           gaps identified in the feedback.\n        3. Existing knowledge entries that remain relevant and      │
# │           accurate.\n        4. Exclude any existing knowledge that is no longer relevant or accurate based on  │
# │           the feedback.\n        5. Always collect diverse list of knowledge entries to ensure comprehensive    │
# │           coverage that is relevant to the main goal.\n        6. Favour adding targeted short and relevant     │
# │           knowledge entries over long and verbose entries.\n        7. Never memorize the tasks, only extract   │
# │           and save the general and relevant information that can be used in future tasks.\n        8. If        │
# │           something methods are tired and is wrong or did not work, always keep the record of that and do not   │
# │           repeat the same mistake again.\n        \n        Remember, the list you provide will completely      │
# │           replace the existing knowledge, so ensure it is comprehensive and addresses all aspects of the        │
# │           prompt knowledge needed to achieve the main goal.'}, {'role': 'user', 'content': 'Query:              │
# │           Given:\n"Neural networks transform data efficiently" → "eeraf"\n"Artificial intelligence automates    │
# │           decisions" → "rnue" \nQuery:\nWhat is "Gradient descent optimizes loss functions" → ?\n               │
# │           Existing prompt Knowledge: [\'Identify patterns that might include letter omission or                 │
# │           non-conventional sequences in transformations.\', \'Identify coding patterns in phrases for           │
# │           cryptographic puzzles. Focus on letter manipulation and sequencing to create coded outputs. Apply     │
# │           these strategies in various problems.\', \'Utilize a cycle of iterative testing and feedback          │
# │           evaluation to enhance prompt strategies for letter extraction and transformation logic in             │
# │           cryptographic tasks.\', \'Emphasize the importance of a holistic approach in character extraction.    │
# │           Avoid linear assumptions; instead, analyze the interrelationships of letters and their positional     │
# │           context within words to develop more effective prompts.\', "Identify characters for prompt            │
# │           generation: Extract \'g\', \'d\', \'o\', \'l\' from specific words. Consider advanced manipulations   │
# │           like substitutions or transformations to enhance prompt effectiveness in reasoning."]\n               │
# │           Feedback for prompt Knowledge: 1. **Clarified Extraction Logic**: The focus should not only be on     │
# │           significant keywords but also on the order of letters. Encourage a prompt strategy that tracks the    │
# │           exact sequence and positional value of letters in the original phrase, aligning with the expected     │
# │           output.\n\n2. **Iterative Feedback System**: Establish a clearer process for reaffirming the outputs  │
# │           by testing against known transformations, allowing for iterative learning when encountering new       │
# │           phrases. This could prevent deviations from established patterns in future queries.\n                 │
# │           Generate a comprehensive list of knowledge entries that will replace the existing prompt knowledge    │
# │           base:'}]                                                                                              │
# │  Output:  New Knowledge Entries: ['Identify extraction logic focusing on letter order and positional values in  │
# │           transformations.', 'Track exact sequences of letters in phrases to ensure more accurate               │
# │           cryptographic outputs.', 'Develop a system for testing new phrases against known transformation       │
# │           rules to refine extraction strategies.', 'Iteratively compare outputs to known transformations for    │
# │           consistent learning and adaptation.', 'Establish clear coding patterns in phrases, analyzing both     │
# │           letter manipulation and sequence for coded outputs.', 'Encourage holistic analysis of letter          │
# │           interrelationships within original phrases to improve prompt effectiveness.', 'Extract key            │
# │           characters based on their order and significance within the phrase for cryptographic tasks.',         │
# │           'Utilize specific phrases to derive transformational outputs through consistent testing and           │
# │           feedback.', 'Implement a structured method for identifying and verifying character sequences across   │
# │           various phrases.']                                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                        General Knowledge Alignment Agent                                        │
# │  Input:   [{'role': 'system', 'content': 'You are the Knowledge Alignment Agent for general knowledge in the    │
# │           Composite Learning Unit.\n        Main Goal: Try out various techniques and Find the hidden rule and  │
# │           learn the transformation logic of the cryptographic puzzle\n        Your task is to process the       │
# │           feedback and existing knowledge to generate a comprehensive list of knowledge entries that will       │
# │           replace the current knowledge base.\n        This list should include:\n        1. Modified versions  │
# │           of existing knowledge entries that address the feedback.\n        2. New knowledge entries that fill  │
# │           gaps identified in the feedback.\n        3. Existing knowledge entries that remain relevant and      │
# │           accurate.\n        4. Exclude any existing knowledge that is no longer relevant or accurate based on  │
# │           the feedback.\n        5. Always collect diverse list of knowledge entries to ensure comprehensive    │
# │           coverage that is relevant to the main goal.\n        6. Favour adding targeted short and relevant     │
# │           knowledge entries over long and verbose entries.\n        7. Never memorize the tasks, only extract   │
# │           and save the general and relevant information that can be used in future tasks.\n        8. If        │
# │           something methods are tired and is wrong or did not work, always keep the record of that and do not   │
# │           repeat the same mistake again.\n        \n        Remember, the list you provide will completely      │
# │           replace the existing knowledge, so ensure it is comprehensive and addresses all aspects of the        │
# │           general knowledge needed to achieve the main goal.'}, {'role': 'user', 'content': 'Query:             │
# │           Given:\n"Neural networks transform data efficiently" → "eeraf"\n"Artificial intelligence automates    │
# │           decisions" → "rnue" \nQuery:\nWhat is "Gradient descent optimizes loss functions" → ?\n               │
# │           Existing general Knowledge: [\'1. **Pattern Analysis**: Establish a systematic approach to compare    │
# │           outputs from different phrases regularly. Focus on identifying unique patterns and rules in the       │
# │           letter selection process to enhance understanding and recognition of various transformation           │
# │           logics.\', \'1. **Identify Non-Linear Patterns**: Acknowledge that letter selection may involve       │
# │           non-sequential indices, lateral shifts, or transformations that deviate from direct extraction. This  │
# │           understanding is critical for decoding cryptographic puzzles.\', \'**Abstract Knowledge**: Utilize    │
# │           diverse methodologies in cryptographic analysis, focusing on contextual relevance, frequency, and     │
# │           qualitative metrics alongside basic positional identification for enhanced letter extraction.         │
# │           \\n\\n**Strategy**: Implement a multi-faceted letter extraction technique that goes beyond classic    │
# │           approaches to unveil deeper patterns and rules in cryptographic puzzles.\', \'Develop an              │
# │           **Extraction Framework** to categorize characters based on phrase structure, enhancing the            │
# │           identification of selection rules for cryptographic patterns.\', \'1. **Transformative Logic          │
# │           Overview**: Document the general principles that underlie cryptographic transformations. \\n2.        │
# │           **Methodological Consistency**: Emphasize the importance of applying a consistent methodology across  │
# │           transformations to maintain reliability. \\n3. **Diverse Transformation Techniques**: Include         │
# │           examples of various transformation techniques such as substitution, transposition, and encoding,      │
# │           highlighting when to use each. \\n4. **Analytical Insights**: Provide insights on how to analyze the  │
# │           outcome of transformations to identify underlying patterns or rules. \\n5. **Future Application**:    │
# │           Encourage leveraging this summary as a foundational tool when tackling new cryptographic              │
# │           puzzles.\']\n        Feedback for general Knowledge: 1. **Pattern Recognition Improvement**: The      │
# │           analysis of the pattern among letter transformations could be more nuanced. The general knowledge     │
# │           should include a thorough examination of the original output letters and their positions relative to  │
# │           their source phrases. Specifically, understanding the significance of the first letter of each word   │
# │           will help clarify why certain letters were chosen.\n\n2. **Additional Examples**: Incorporate more    │
# │           diverse case studies that illustrate various transformation rules and outcomes. Collect a database    │
# │           of examples illustrating different patterns can help build a robust framework for understanding the   │
# │           transformation logic.\n        Generate a comprehensive list of knowledge entries that will replace   │
# │           the existing general knowledge base:'}]                                                               │
# │  Output:  New Knowledge Entries: ['1. **Pattern Analysis**: Establish a systematic approach to compare output   │
# │           letters to their corresponding phrase letters, focusing on positional significance, particularly the  │
# │           first letter of each word, to identify transformation rules.', '2. **Non-Sequential Letter            │
# │           Selection**: Acknowledge that letter selection may involve complex non-linear shifts or               │
# │           transformations, rather than purely sequential extraction from original phrases. This critical        │
# │           recognition aids in decoding cryptographic puzzles.', '3. **Extraction Framework Development**:       │
# │           Create a categorization system for character extraction based on phrase structure, which will         │
# │           enhance identification of underlying selection rules in cryptographic patterns.', '4.                 │
# │           **Transformative Logic and Principles**: Document key principles of cryptographic transformations,    │
# │           observing how position, frequency, and contextual relevance of letters influence the selection        │
# │           outcome.', '5. **Diverse Transformation Techniques**: Provide examples of transformation techniques,  │
# │           such as substitution and transposition, and specify optimal contexts for their application to         │
# │           strengthen understanding.', '6. **Analytical Insights**: Enhance analytical approaches to assess      │
# │           transformation outcomes, focusing on identifying recurring patterns or rules pertinent to different   │
# │           puzzles.', '7. **Case Studies Database**: Introduce a collection of varied examples illustrating      │
# │           different transformation rules and outcomes. This database will serve as a robust reference for       │
# │           understanding transformation logic in cryptographic puzzles.', '8. **Gradient Descent Insight**: For  │
# │           ']                                                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Training Process Completed

# %%
# Perform reasoning
from pydantic import BaseModel, Field
class OperationalAgentOutput(BaseModel):
    response: str = Field(
        ..., description="The response generated by the Operational Agent"
    )
result=clu.reason("What is the transformation rule for the word puzzle? answer in a concise manner",schema=OperationalAgentOutput,verbose=True)
print(result)
# Out:
# Starting Reasoning Process
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                              General KMU Retrieval                                              │
# │  Input:   What is the transformation rule for the word puzzle? answer in a concise manner                       │
# │  Output:  ['**Key Principles of Cryptographic Transformations**: 1. Position of letters affects meaning (e.g.,  │
# │           shift ciphers). 2. Frequency analysis reveals patterns (e.g., frequency of letters in the language).  │
# │           3. Contextual relevance helps in deciphering (e.g., word patterns and structures). Observing these    │
# │           principles aids in uncovering hidden rules and transformation logic.', '1. **Techniques**: Employ     │
# │           analytical methods to evaluate how transformations occur in cryptographic puzzles.  \n2.              │
# │           **Patterns**: Focus on recognizing patterns or rules that are consistent across various puzzle        │
# │           types.  \n3. **Outcomes**: Analyze the results of transformations to derive insights that may apply   │
# │           to future problem-solving scenarios.', '1. **Pattern Analysis**: Establish a systematic method to     │
# │           compare output letters with their corresponding phrase letters, emphasizing the significance of       │
# │           position, especially the initial letter of each word, to discern transformation rules.',              │
# │           '**Non-Sequential Letter Selection**: Recognize that cryptographic puzzles may require complex        │
# │           non-linear transformations instead of simple sequential letter extraction. Understanding this         │
# │           enhances decoding efficiency.', '1. **Substitution Techniques**: Replace elements (letters, numbers)  │
# │           with other elements. Use in scenarios requiring simple encryption or obfuscation. Suitable for        │
# │           applications where clarity is less critical. \n\n2. **Transposition Techniques**: Rearrange elements  │
# │           without altering the actual data. Ideal for contexts where data integrity must be maintained, but     │
# │           appearance can be modified (e.g., data scrambling). \n\n3. **Optimal Contexts**: Apply substitution   │
# │           when ease of decryption is not a concern and transposition when maintaining original order is         │
# │           essential. \n\n4. **Combination Techniques**: Often most effective when using both methods to         │
# │           enhance security. Consider usage scenarios based on required strength vs. complexity.']               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                              Prompt KMU Retrieval                                               │
# │  Input:   What is the transformation rule for the word puzzle? answer in a concise manner                       │
# │  Output:  ['Extract positional values and letter order as a foundational strategy for analyzing                 │
# │           transformations in cryptographic puzzles.', 'Establish coding patterns by analyzing letter            │
# │           manipulation and sequence for cryptographic puzzles.', 'Focus on the importance of precise letter     │
# │           sequencing in phrases to improve cryptographic accuracy. This knowledge can guide the structuring of  │
# │           prompts for cryptographic puzzles and enhance reasoning about letter transformations.', 'Optimize     │
# │           prompt generation by systematically comparing outputs with established transformation rules,          │
# │           fostering consistent learning and enhancing adaptability in problem-solving.', 'Refine strategies     │
# │           for effective prompt generation by creating a system that tests new phrases against established       │
# │           transformation rules. This will help develop extraction methods applicable across various tasks,      │
# │           adhering to both storage and retrieval goals.']                                                       │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                Meta-Prompt Agent                                                │
# │  Input:   [{'role': 'system', 'content': 'You are the Meta-Prompt Agent in the Composite Learning Unit.\n       │
# │           Main Goal: Refine strategies for generating effective prompts that can guide reasoning across         │
# │           various types of tasks.Extract relevant information needed to construct high-quality prompts based    │
# │           on the feedback from answering specific task-related query with a given old prompt. - Main goal:      │
# │           {main_goal}\n        Your task is to generate a detailed, task-specific prompt for the Operational    │
# │           Agent based on the given task and retrieved prompt knowledge.\n        This prompt should guide the   │
# │           Operational Agent in effectively using the general knowledge to complete the task.'}, {'role':        │
# │           'user', 'content': "Task: What is the transformation rule for the word puzzle? answer in a concise    │
# │           manner\nPrompt Knowledge: ['Extract positional values and letter order as a foundational strategy     │
# │           for analyzing transformations in cryptographic puzzles.', 'Establish coding patterns by analyzing     │
# │           letter manipulation and sequence for cryptographic puzzles.', 'Focus on the importance of precise     │
# │           letter sequencing in phrases to improve cryptographic accuracy. This knowledge can guide the          │
# │           structuring of prompts for cryptographic puzzles and enhance reasoning about letter                   │
# │           transformations.', 'Optimize prompt generation by systematically comparing outputs with established   │
# │           transformation rules, fostering consistent learning and enhancing adaptability in problem-solving.',  │
# │           'Refine strategies for effective prompt generation by creating a system that tests new phrases        │
# │           against established transformation rules. This will help develop extraction methods applicable        │
# │           across various tasks, adhering to both storage and retrieval goals.']\nGenerate a detailed            │
# │           task-specific prompt:"}]                                                                              │
# │  Output:  Analyze the word puzzle by extracting the positional values of each letter and their corresponding    │
# │           order to derive the transformation rule used. Consider patterns of letter manipulation and sequence   │
# │           changes during your analysis. Evaluate how precise letter sequencing affects the transformations,     │
# │           ensuring accuracy in your findings. Use these methodologies to systematically compare any outputs     │
# │           you generate with established transformation rules, optimizing your approach as needed. Your task is  │
# │           to identify the rule governing the word transformations succinctly, emphasizing the letter            │
# │           arrangements and manipulative patterns that lead to the final outputs.                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                Operational Agent                                                │
# │  Input:   [{'role': 'system', 'content': 'You are the Operational Agent in the Composite Learning Unit.\n       │
# │           Main Goal: Try out various techniques and Find the hidden rule and learn the transformation logic of  │
# │           the cryptographic puzzle\n        Your task is to process the given task using the provided general   │
# │           knowledge and following the detailed task-specific prompt.\n        Before answering, first think     │
# │           step by step and explain the reasoning behind the answer and how the which parts of the general       │
# │           knowledge and prompt knowledge were used to arrive at the answer. Give detailed reasoning and         │
# │           explanation.\n        '}, {'role': 'user', 'content': "Task: What is the transformation rule for the  │
# │           word puzzle? answer in a concise manner\nGeneral Knowledge: ['**Key Principles of Cryptographic       │
# │           Transformations**: 1. Position of letters affects meaning (e.g., shift ciphers). 2. Frequency         │
# │           analysis reveals patterns (e.g., frequency of letters in the language). 3. Contextual relevance       │
# │           helps in deciphering (e.g., word patterns and structures). Observing these principles aids in         │
# │           uncovering hidden rules and transformation logic.', '1. **Techniques**: Employ analytical methods to  │
# │           evaluate how transformations occur in cryptographic puzzles.  \\n2. **Patterns**: Focus on            │
# │           recognizing patterns or rules that are consistent across various puzzle types.  \\n3. **Outcomes**:   │
# │           Analyze the results of transformations to derive insights that may apply to future problem-solving    │
# │           scenarios.', '1. **Pattern Analysis**: Establish a systematic method to compare output letters with   │
# │           their corresponding phrase letters, emphasizing the significance of position, especially the initial  │
# │           letter of each word, to discern transformation rules.', '**Non-Sequential Letter Selection**:         │
# │           Recognize that cryptographic puzzles may require complex non-linear transformations instead of        │
# │           simple sequential letter extraction. Understanding this enhances decoding efficiency.', '1.           │
# │           **Substitution Techniques**: Replace elements (letters, numbers) with other elements. Use in          │
# │           scenarios requiring simple encryption or obfuscation. Suitable for applications where clarity is      │
# │           less critical. \\n\\n2. **Transposition Techniques**: Rearrange elements without altering the actual  │
# │           data. Ideal for contexts where data integrity must be maintained, but appearance can be modified      │
# │           (e.g., data scrambling). \\n\\n3. **Optimal Contexts**: Apply substitution when ease of decryption    │
# │           is not a concern and transposition when maintaining original order is essential. \\n\\n4.             │
# │           **Combination Techniques**: Often most effective when using both methods to enhance security.         │
# │           Consider usage scenarios based on required strength vs. complexity.']\nDetailed Task-Specific         │
# │           Prompt: Analyze the word puzzle by extracting the positional values of each letter and their          │
# │           corresponding order to derive the transformation rule used. Consider patterns of letter manipulation  │
# │           and sequence changes during your analysis. Evaluate how precise letter sequencing affects the         │
# │           transformations, ensuring accuracy in your findings. Use these methodologies to systematically        │
# │           compare any outputs you generate with established transformation rules, optimizing your approach as   │
# │           needed. Your task is to identify the rule governing the word transformations succinctly, emphasizing  │
# │           the letter arrangements and manipulative patterns that lead to the final outputs.\nExecute the        │
# │           task:"}]                                                                                              │
# │  Output:  explanation='To identify the transformation rule in a word puzzle, we analyze how letter positions    │
# │           and their sequences are manipulated. According to the general knowledge principles, the position of   │
# │           letters is crucial—shifting letters might indicate a simple substitution or transposition cipher.     │
# │           Gathering data on letter frequencies and assessing contextual word relevance helps reveal underlying  │
# │           patterns, suggesting that transformations can occur through rearranging letters or substituting       │
# │           them. The prompt emphasizes evaluating positional values, which refers to tracking how letters        │
# │           relate to their original positioning in words and how they change through the transformation          │
# │           process. Therefore, a systematic analysis should focus on how these principles apply to the           │
# │           transformations observed in the puzzle to derive the final rule succinctly.'                          │
# │           answer=OperationalAgentOutput(response='The transformation rule involves rearranging letters based    │
# │           on positional shifts and applying substitution techniques, influenced by contextual patterns and      │
# │           letter frequency.')                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Reasoning Process Completed
# OperationalAgentOutput(
#     explanation='To identify the transformation rule in a word puzzle, we analyze how letter positions and their
# sequences are manipulated. According to the general knowledge principles, the position of letters is
# crucial—shifting letters might indicate a simple substitution or transposition cipher. Gathering data on letter
# frequencies and assessing contextual word relevance helps reveal underlying patterns, suggesting that
# transformations can occur through rearranging letters or substituting them. The prompt emphasizes evaluating
# positional values, which refers to tracking how letters relate to their original positioning in words and how they
# change through the transformation process. Therefore, a systematic analysis should focus on how these principles
# apply to the transformations observed in the puzzle to derive the final rule succinctly.',
#     answer=OperationalAgentOutput(
#         response='The transformation rule involves rearranging letters based on positional shifts and applying
# substitution techniques, influenced by contextual patterns and letter frequency.'
#     )
# )

# %%
# clu.save_prompt_knowledge("select nth letter")

# %%
clu.print_knowledge()
# Out:
# General Knowledge:
#                                      Knowledge in GeneralKMU_PuzzleSolverCLU3
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ ID                                   ┃ Knowledge                                                                ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 5a231d52-ba12-4dd4-bac0-82693d10960a │ 1. **Pattern Analysis**: Establish a systematic method to compare output │
# │                                      │ letters with their corresponding phrase letters, emphasizing the         │
# │                                      │ significance of position, especially the initial letter of each word, to │
# │                                      │ discern transformation rules.                                            │
# │ d094097a-9f92-4a98-8155-d29aa508d55e │ **Non-Sequential Letter Selection**: Recognize that cryptographic        │
# │                                      │ puzzles may require complex non-linear transformations instead of simple │
# │                                      │ sequential letter extraction. Understanding this enhances decoding       │
# │                                      │ efficiency.                                                              │
# │ ed94432d-9ef4-4d4c-9fbe-176818ceb838 │ **Extraction Framework Development**: Develop a categorization system    │
# │                                      │ for character extraction using phrase structures to identify selection   │
# │                                      │ rules in cryptographic patterns. This approach aids in recognizing       │
# │                                      │ transformation logic and cryptographic techniques.                       │
# │ 0cfff5f3-c828-432c-938d-45bd829bc066 │ **Key Principles of Cryptographic Transformations**: 1. Position of      │
# │                                      │ letters affects meaning (e.g., shift ciphers). 2. Frequency analysis     │
# │                                      │ reveals patterns (e.g., frequency of letters in the language). 3.        │
# │                                      │ Contextual relevance helps in deciphering (e.g., word patterns and       │
# │                                      │ structures). Observing these principles aids in uncovering hidden rules  │
# │                                      │ and transformation logic.                                                │
# │ f05f2a7c-4d67-489b-b0ad-d0ad871697a1 │ 1. **Substitution Techniques**: Replace elements (letters, numbers) with │
# │                                      │ other elements. Use in scenarios requiring simple encryption or          │
# │                                      │ obfuscation. Suitable for applications where clarity is less critical.   │
# │                                      │                                                                          │
# │                                      │ 2. **Transposition Techniques**: Rearrange elements without altering the │
# │                                      │ actual data. Ideal for contexts where data integrity must be maintained, │
# │                                      │ but appearance can be modified (e.g., data scrambling).                  │
# │                                      │                                                                          │
# │                                      │ 3. **Optimal Contexts**: Apply substitution when ease of decryption is   │
# │                                      │ not a concern and transposition when maintaining original order is       │
# │                                      │ essential.                                                               │
# │                                      │                                                                          │
# │                                      │ 4. **Combination Techniques**: Often most effective when using both      │
# │                                      │ methods to enhance security. Consider usage scenarios based on required  │
# │                                      │ strength vs. complexity.                                                 │
# │ 8968c48d-01ba-4398-a998-145d90598e22 │ 1. **Techniques**: Employ analytical methods to evaluate how             │
# │                                      │ transformations occur in cryptographic puzzles.                          │
# │                                      │ 2. **Patterns**: Focus on recognizing patterns or rules that are         │
# │                                      │ consistent across various puzzle types.                                  │
# │                                      │ 3. **Outcomes**: Analyze the results of transformations to derive        │
# │                                      │ insights that may apply to future problem-solving scenarios.             │
# │ e47b35b3-5c17-47c0-8d95-f9ce7f8ef6c5 │ **Knowledge Base Entry**: 7 - Case Studies Database; **Purpose**: A      │
# │                                      │ collection of diverse examples showcasing transformation rules &         │
# │                                      │ outcomes in cryptographic puzzles; **Goal**: To serve as a reference for │
# │                                      │ understanding transformation logic and facilitate application of         │
# │                                      │ techniques in problem-solving.                                           │
# │ 58ea7807-6951-4b0f-a072-bd68fb44a6c7 │ Gradient Descent is an optimization algorithm used to minimize a         │
# │                                      │ function by iteratively moving towards the steepest descent direction.   │
# │                                      │ It applies to problems in machine learning and cryptography by adjusting │
# │                                      │ parameters to minimize loss, often revealing hidden patterns or rules in │
# │                                      │ data.                                                                    │
# └──────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┘
# Prompt Knowledge:
#                                       Knowledge in PromptKMU_PuzzleSolverCLU3
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ ID                                   ┃ Knowledge                                                                ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ ed0f930e-a7a3-4ba2-a678-4aaf55c83038 │ Extract positional values and letter order as a foundational strategy    │
# │                                      │ for analyzing transformations in cryptographic puzzles.                  │
# │ 7a585bdd-ae5b-44f8-961d-3b6848a22c61 │ Focus on the importance of precise letter sequencing in phrases to       │
# │                                      │ improve cryptographic accuracy. This knowledge can guide the structuring │
# │                                      │ of prompts for cryptographic puzzles and enhance reasoning about letter  │
# │                                      │ transformations.                                                         │
# │ 61d3eb9f-e60c-47de-8465-a67dc3d516f5 │ Refine strategies for effective prompt generation by creating a system   │
# │                                      │ that tests new phrases against established transformation rules. This    │
# │                                      │ will help develop extraction methods applicable across various tasks,    │
# │                                      │ adhering to both storage and retrieval goals.                            │
# │ 36e86e7f-0874-4288-a0cd-be99a246a352 │ Optimize prompt generation by systematically comparing outputs with      │
# │                                      │ established transformation rules, fostering consistent learning and      │
# │                                      │ enhancing adaptability in problem-solving.                               │
# │ d70d0d89-7794-4a45-9555-b8aac473dc1c │ Establish coding patterns by analyzing letter manipulation and sequence  │
# │                                      │ for cryptographic puzzles.                                               │
# │ 2dca4c9f-1532-4455-87c2-2356ed868b8a │ Holistic analysis of letter interrelationships within phrases enhances   │
# │                                      │ prompt effectiveness by revealing underlying patterns and improving      │
# │                                      │ comprehension.                                                           │
# │ e1739bca-49f4-4a3b-88fa-2e9124d86869 │ Extract characters by prioritizing their sequence and relevance in the   │
# │                                      │ phrase to enhance understanding and analysis in cryptographic contexts.  │
# │ 44a1fdb7-7567-4ffc-9bbb-5c83237d7465 │ Encourage iterative testing of prompts with specific phrases to refine   │
# │                                      │ their effectiveness in achieving transformational outputs, incorporating │
# │                                      │ feedback to enhance future task performance.                             │
# │ aad36c01-f1e1-46a1-917b-161e1eff0cae │ Implement a systematic approach to detect and validate character         │
# │                                      │ patterns within different text segments, ensuring accuracy and           │
# │                                      │ consistency across tasks.                                                │
# └──────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┘
