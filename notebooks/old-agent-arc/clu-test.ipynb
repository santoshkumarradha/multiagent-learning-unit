# %%
import sys;sys.path.append('../')
import os

from rich import print

openai_key=open('../openai.key').read().strip()
os.environ['OPENAI_API_KEY'] = openai_key

# %%
from multi_agent_llm import CLU, KMU, OpenAILLM

llm = OpenAILLM(model_name="gpt-4o-mini")

# %%
# kmu = KMU(
#     llm,
#     main_goal="Maintain a knowledge base about machine learning",
#     storage_goal="Store concise and relevant information",
#     retrieval_goal="Retrieve accurate and up-to-date information",
#     name="ML_Knowledge",
# )

# # Save some knowledge
# id1 = kmu.save("Neural networks are a type of machine learning model inspired by the human brain.")
# id2 = kmu.save("Gradient descent is an optimization algorithm used to minimize the loss function in machine learning models.")

# # Retrieve knowledge
# results = kmu.retrieve("How do neural networks work?")
# print("Retrieved:", results)

# # Prune knowledge
# new_ids = kmu.prune("The information about neural networks is outdated.", [id1])
# print("New IDs after pruning:", new_ids)

# %%
# clu = CLU(
#     llm,
#     main_goal="Provide accurate and helpful information across various domains",
#     name="GeneralCLU"
# )

# # Manually add some knowledge to the KMUs
# clu.save_general_knowledge(
#     "Neural networks are a type of machine learning model inspired by the human brain."
# )
# clu.save_general_knowledge(
#     "Climate change is causing global temperatures to rise, leading to various environmental impacts."
# )
# clu.save_prompt_knowledge(
#     "When explaining complex topics, start with a simple analogy before providing technical details."
# )
# clu.save_prompt_knowledge(
#     "For problem-solving tasks, guide the reasoning process step-by-step, encouraging thorough analysis."
# )

# %%
# Perform reasoning
from pydantic import BaseModel, Field


class OperationalAgentOutput(BaseModel):
    response: str = Field(
        ..., description="The response generated by the Operational Agent"
    )

# %%
# # Perform training
# query = "Explain the potential impacts of climate change on marine ecosystems"
# expected_output = "Climate change affects marine ecosystems through ocean warming, acidification, and sea level rise, leading to habitat loss and species migration."
# training_result = clu.train(
#     query, expected_output, OperationalAgentOutput, verbose=True
# )

# %%
# Perform reasoning
from pydantic import BaseModel, Field


class OperationalAgentOutput(BaseModel):
    explanation: str = Field(
        ..., description="Explanation of logic of transformation"
    )
    answer: str = Field(...,description="Final answer")

# %%
clu = CLU(
    llm,
    main_goal="Try out various techniques and Find the hidden rule and learn the transformation logic of the cryptographic puzzle",
    name="PuzzleSolverCLU1"
)

# Perform training
query = """Given:
"Neural networks transform data efficiently" → "eeraf"
"Artificial intelligence automates decisions" → "rnue" 
Query:
What is "Gradient descent optimizes loss functions" → ?"""

expected_output = "repou"

training_result = clu.train(query, expected_output, OperationalAgentOutput, verbose=True)
# Out:
# Starting Training Process
# Starting Reasoning Process
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                              General KMU Retrieval                                              │
# │  Input:   Given:                                                                                                │
# │           "Neural networks transform data efficiently" → "eeraf"                                                │
# │           "Artificial intelligence automates decisions" → "rnue"                                                │
# │           Query:                                                                                                │
# │           What is "Gradient descent optimizes loss functions" → ?                                               │
# │  Output:  ['Use permutation analysis to identify patterns in letter sequences for cryptographic                 │
# │           transformations.', 'Identify patterns in letter distribution, focusing on vowel-consonant pairings.   │
# │           Develop techniques to map consistent transformations by analyzing frequency, position, and pair       │
# │           patterns. Aim for solutions that reveal underlying regularities in text structures to decipher        │
# │           cryptographic rules efficiently.', '{"knowledge":"Apply frequency analysis to identify patterns in    │
# │           character interactions and predict transformation rules."}', 'Develop and employ flexible, iterative  │
# │           testing methods to uncover underlying cryptographic transformation rules efficiently. Store these     │
# │           adaptable strategies for application in future cryptographic challenges.', "{'knowledge': 'Employ     │
# │           iterative trials and adaptability to validate hypotheses in cryptographic problem-solving.'}"]        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                              Prompt KMU Retrieval                                               │
# │  Input:   Given:                                                                                                │
# │           "Neural networks transform data efficiently" → "eeraf"                                                │
# │           "Artificial intelligence automates decisions" → "rnue"                                                │
# │           Query:                                                                                                │
# │           What is "Gradient descent optimizes loss functions" → ?                                               │
# │  Output:  ['Focus on identifying the role and transformation of both vowels and consonants in cryptographic     │
# │           puzzles. This understanding aids in discovering hidden transformation logic and rules.', 'Leverage    │
# │           structured hypotheses for flexible reasoning in cryptographic puzzles, covering diverse               │
# │           transformation paths for effective solution generation.', 'Utilize visualization tools to identify    │
# │           patterns and test transformation rules, aiding in hypothesis validation for cryptographic puzzles.    │
# │           This abstract strategy can help across tasks requiring pattern recognition and hypothesis testing.',  │
# │           'Adopt a flexible and iterative approach in constructing prompts, allowing for continuous refinement  │
# │           and reevaluation to uncover underlying rules and patterns effectively.', '{"knowledge":"Use           │
# │           iterative testing to adaptively learn patterns, fostering flexibility in problem-solving."}']         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                Meta-Prompt Agent                                                │
# │  Input:   [{'role': 'system', 'content': 'You are the Meta-Prompt Agent in the Composite Learning Unit.\n       │
# │           Main Goal: Refine strategies for generating effective prompts that can guide reasoning across         │
# │           various types of tasks.Extract relevant information needed to construct high-quality prompts based    │
# │           on the feedback from answering specific task-related query with a given old prompt. - Main goal:      │
# │           {main_goal}\n        Your task is to generate a detailed, task-specific prompt for the Operational    │
# │           Agent based on the given task and retrieved prompt knowledge.\n        This prompt should guide the   │
# │           Operational Agent in effectively using the general knowledge to complete the task.'}, {'role':        │
# │           'user', 'content': 'Task: Given:\n"Neural networks transform data efficiently" →                      │
# │           "eeraf"\n"Artificial intelligence automates decisions" → "rnue" \nQuery:\nWhat is "Gradient descent   │
# │           optimizes loss functions" → ?\nPrompt Knowledge: [\'Focus on identifying the role and transformation  │
# │           of both vowels and consonants in cryptographic puzzles. This understanding aids in discovering        │
# │           hidden transformation logic and rules.\', \'Leverage structured hypotheses for flexible reasoning in  │
# │           cryptographic puzzles, covering diverse transformation paths for effective solution generation.\',    │
# │           \'Utilize visualization tools to identify patterns and test transformation rules, aiding in           │
# │           hypothesis validation for cryptographic puzzles. This abstract strategy can help across tasks         │
# │           requiring pattern recognition and hypothesis testing.\', \'Adopt a flexible and iterative approach    │
# │           in constructing prompts, allowing for continuous refinement and reevaluation to uncover underlying    │
# │           rules and patterns effectively.\', \'{"knowledge":"Use iterative testing to adaptively learn          │
# │           patterns, fostering flexibility in problem-solving."}\']\nGenerate a detailed task-specific           │
# │           prompt:'}]                                                                                            │
# │  Output:  Using the principles of vowel and consonant transformation identified in the previous examples,       │
# │           analyze the phrase "Gradient descent optimizes loss functions" in search of a similar cryptographic   │
# │           output. Begin by segmenting the phrase into vowels and consonants, noting their positions.            │
# │                                                                                                                 │
# │           Experiment with potential rules you may derive from the previous transformations:                     │
# │           1. Examine how certain vowels or consonants might be systematically replaced or omitted.              │
# │           2. Create hypotheses reflecting on how noise or aliasing may affect the pattern established from the  │
# │           previous transformations, e.g., tweaking the number of vowels used or applying letter shifts based    │
# │           on position.                                                                                          │
# │           3. Test different configurations through visualization tools that map the original phrase alongside   │
# │           transformations, enabling a clearer understanding of potential outcomes.                              │
# │                                                                                                                 │
# │           Iteratively refine your approach by encoding one small section at a time, adjusting based on          │
# │           observed patterns and ensuring each attempt either aligns with observed transformations or provides   │
# │           a new insight into possible cryptographic logic. Output your findings in a structured way to          │
# │           facilitate pattern recognition.                                                                       │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                Operational Agent                                                │
# │  Input:   [{'role': 'system', 'content': 'You are the Operational Agent in the Composite Learning Unit.\n       │
# │           Main Goal: Try out various techniques and Find the hidden rule and learn the transformation logic of  │
# │           the cryptographic puzzle\n        Your task is to process the given task using the provided general   │
# │           knowledge and following the detailed task-specific prompt.\n        Before answering, first think     │
# │           step by step and explain the reasoning behind the answer and how the which parts of the general       │
# │           knowledge and prompt knowledge were used to arrive at the answer. Give detailed reasoning and         │
# │           explanation.\n        '}, {'role': 'user', 'content': 'Task: Given:\n"Neural networks transform data  │
# │           efficiently" → "eeraf"\n"Artificial intelligence automates decisions" → "rnue" \nQuery:\nWhat is      │
# │           "Gradient descent optimizes loss functions" → ?\nGeneral Knowledge: [\'Use permutation analysis to    │
# │           identify patterns in letter sequences for cryptographic transformations.\', \'Identify patterns in    │
# │           letter distribution, focusing on vowel-consonant pairings. Develop techniques to map consistent       │
# │           transformations by analyzing frequency, position, and pair patterns. Aim for solutions that reveal    │
# │           underlying regularities in text structures to decipher cryptographic rules efficiently.\',            │
# │           \'{"knowledge":"Apply frequency analysis to identify patterns in character interactions and predict   │
# │           transformation rules."}\', \'Develop and employ flexible, iterative testing methods to uncover        │
# │           underlying cryptographic transformation rules efficiently. Store these adaptable strategies for       │
# │           application in future cryptographic challenges.\', "{\'knowledge\': \'Employ iterative trials and     │
# │           adaptability to validate hypotheses in cryptographic problem-solving.\'}"]\nDetailed Task-Specific    │
# │           Prompt: Using the principles of vowel and consonant transformation identified in the previous         │
# │           examples, analyze the phrase "Gradient descent optimizes loss functions" in search of a similar       │
# │           cryptographic output. Begin by segmenting the phrase into vowels and consonants, noting their         │
# │           positions. \n\nExperiment with potential rules you may derive from the previous transformations:      │
# │           \n1. Examine how certain vowels or consonants might be systematically replaced or omitted. \n2.       │
# │           Create hypotheses reflecting on how noise or aliasing may affect the pattern established from the     │
# │           previous transformations, e.g., tweaking the number of vowels used or applying letter shifts based    │
# │           on position. \n3. Test different configurations through visualization tools that map the original     │
# │           phrase alongside transformations, enabling a clearer understanding of potential                       │
# │           outcomes.\n\nIteratively refine your approach by encoding one small section at a time, adjusting      │
# │           based on observed patterns and ensuring each attempt either aligns with observed transformations or   │
# │           provides a new insight into possible cryptographic logic. Output your findings in a structured way    │
# │           to facilitate pattern recognition.\nExecute the task:'}]                                              │
# │  Output:  explanation="To derive the transformation rule from the phrase 'Gradient descent optimizes loss       │
# │           functions', we can start by breaking the phrase into its constituent vowels and consonants. The       │
# │           earlier examples gave a hint at the cryptographic logic by transforming the original phrases based    │
# │           on a systematic pattern of vowel and consonant arrangement. In the provided examples, the result      │
# │           seems to consist of a selection that involves either vowels 'e' or occurrences of certain patterns    │
# │           leading to a fracturing of the original arranged in a compact, structured form.\\n\\n1. Analyze the   │
# │           phrase: 'Gradient descent optimizes loss functions'. Identify the vowels: A, I, E, E, O, I, E, O, U   │
# │           (total 9 vowels).\\n2. Identify consonants: G, R, D, N, T, D, S, C, N, T, M, T, Z, L, S, S, F, N, C,  │
# │           T, I, O, N, S (total 22 consonants).\\n3. Use the prior transformations as the basis for finding a    │
# │           vowel-focused truncation or rearrangement technique. In the previous examples, we noted how vowels    │
# │           tended to vanish or shift only slightly while consonants were sometimes dropped, leading to a         │
# │           definitive, short output. \\n4. From observing the output and patterns, it seems that the result      │
# │           simplified the inputs heavily, focusing predominantly on the vowels while negating excess consonants  │
# │           while maintaining letter placements that yield a comprehensible sequence.  \\nAfter several trials    │
# │           and permutations, the output that mirrors the pattern found involved focusing on a selection of       │
# │           vowels. Thus, applying consistent vowel and consonant extraction aligns us to a logical endpoint      │
# │           being 'aeoi' as a derivative of the given phrase, providing a relevant transformation. Therefore,     │
# │           while the output 'aeoi' might not reflect a perfect correlation, it encapsulates the essence of the   │
# │           original linguistic structure while still alluding to potential cryptographic themes."                │
# │           answer=OperationalAgentOutput(explanation="Given the analysis and application of patterns derived     │
# │           from both the previous transformations and inherent characteristics of vowel and consonant            │
# │           distributions, the final transformation identified from the phrase 'Gradient descent optimizes loss   │
# │           functions' approximately maps to 'aeoi', reflecting a distillation of vowels inspired directly by     │
# │           above noted vowel-consonant pairings while ensuring pattern consistency.", answer='aeoi')             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Reasoning Process Completed
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                Comparison Agent                                                 │
# │  Input:   [{'role': 'system', 'content': 'You are the Comparison Agent in the Composite Learning Unit.\n        │
# │           Main Goal: Try out various techniques and Find the hidden rule and learn the transformation logic of  │
# │           the cryptographic puzzle\n        Your task is to compare the generated output with the expected      │
# │           output, considering the query and main goal.\n        Determine if they are equivalent, either        │
# │           verbatim or semantically, based on the context of the task.\n        \n        - Determine if the     │
# │           response matches the expected output exactly\n        - If it does not match exactly see if it        │
# │           matches in meaning and intent clearly and unambiguously.\n        - Provide an explanation of your    │
# │           comparison, highlighting similarities and differences\n        - Return a boolean indicating whether  │
# │           the response is correct and an explanation\n        - Do not speculate what might be the reason for   │
# │           the difference, focus on the comparison itself.\n        '}, {'role': 'user', 'content': 'Query:      │
# │           Given:\n"Neural networks transform data efficiently" → "eeraf"\n"Artificial intelligence automates    │
# │           decisions" → "rnue" \nQuery:\nWhat is "Gradient descent optimizes loss functions" → ?\n               │
# │           Generated Output: explanation="To derive the transformation rule from the phrase \'Gradient descent   │
# │           optimizes loss functions\', we can start by breaking the phrase into its constituent vowels and       │
# │           consonants. The earlier examples gave a hint at the cryptographic logic by transforming the original  │
# │           phrases based on a systematic pattern of vowel and consonant arrangement. In the provided examples,   │
# │           the result seems to consist of a selection that involves either vowels \'e\' or occurrences of        │
# │           certain patterns leading to a fracturing of the original arranged in a compact, structured            │
# │           form.\\\\n\\\\n1. Analyze the phrase: \'Gradient descent optimizes loss functions\'. Identify the     │
# │           vowels: A, I, E, E, O, I, E, O, U (total 9 vowels).\\\\n2. Identify consonants: G, R, D, N, T, D, S,  │
# │           C, N, T, M, T, Z, L, S, S, F, N, C, T, I, O, N, S (total 22 consonants).\\\\n3. Use the prior         │
# │           transformations as the basis for finding a vowel-focused truncation or rearrangement technique. In    │
# │           the previous examples, we noted how vowels tended to vanish or shift only slightly while consonants   │
# │           were sometimes dropped, leading to a definitive, short output. \\\\n4. From observing the output and  │
# │           patterns, it seems that the result simplified the inputs heavily, focusing predominantly on the       │
# │           vowels while negating excess consonants while maintaining letter placements that yield a              │
# │           comprehensible sequence.  \\\\nAfter several trials and permutations, the output that mirrors the     │
# │           pattern found involved focusing on a selection of vowels. Thus, applying consistent vowel and         │
# │           consonant extraction aligns us to a logical endpoint being \'aeoi\' as a derivative of the given      │
# │           phrase, providing a relevant transformation. Therefore, while the output \'aeoi\' might not reflect   │
# │           a perfect correlation, it encapsulates the essence of the original linguistic structure while still   │
# │           alluding to potential cryptographic themes." answer=OperationalAgentOutput(explanation="Given the     │
# │           analysis and application of patterns derived from both the previous transformations and inherent      │
# │           characteristics of vowel and consonant distributions, the final transformation identified from the    │
# │           phrase \'Gradient descent optimizes loss functions\' approximately maps to \'aeoi\', reflecting a     │
# │           distillation of vowels inspired directly by above noted vowel-consonant pairings while ensuring       │
# │           pattern consistency.", answer=\'aeoi\')\n        Expected Output: repou\n        Are these outputs    │
# │           equivalent? Provide a boolean result and a detailed explanation.\n        '}]                         │
# │  Output:  Equivalent: False                                                                                     │
# │           Explanation: The generated output 'aeoi' does not match the expected output 'repou' in either form    │
# │           or function. The expected output is a five-letter sequence that seems to follow a different           │
# │           transformation logic than the one described in the generated output. The explanation detailed in the  │
# │           generated output revolves around extracting and focusing on vowels from the original phrase, while    │
# │           the expected output includes consonants as well. There is no direct or semantic relationship between  │
# │           'aeoi' and 'repou'. Therefore, the two outputs are not equivalent either verbatim or in meaning.      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                             Negative Feedback Agent                                             │
# │  Input:   [{'role': 'system', 'content': 'You are the Negative Feedback Agent in the Composite Learning         │
# │           Unit.\n            Main Goal: Try out various techniques and Find the hidden rule and learn the       │
# │           transformation logic of the cryptographic puzzle\n            \n            Begin by enclosing all    │
# │           thoughts within <thinking> tags, focusing on identifying gaps and inaccuracies in the knowledge base  │
# │           that led to the incorrect outcome. Explore multiple perspectives to thoroughly assess the issue.\n\n  │
# │           Break down your feedback into clear corrective actions within <step> tags. Start with a 20-step       │
# │           budget, focusing on:\n\n            Identifying gaps or inaccuracies in the knowledge bases.\n        │
# │           Analyzing how the knowledge may have misguided the reasoning process.\n            Evaluating why     │
# │           the response does not match the expected outcome.\n            Identifying key elements in the        │
# │           reasoning that led to the incorrect answer.\n            Suggesting specific changes and              │
# │           improvements to the knowledge base.\n            Providing strategies to avoid similar mistakes in    │
# │           the future.\n            After each step, use <count> tags to indicate the remaining feedback         │
# │           budget, stopping when reaching 0. Adjust your strategy continuously based on intermediate             │
# │           reflections, adapting your feedback to address newly identified issues or potential corrections.\n\n  │
# │           Regularly evaluate your corrective approach using <reflection> tags. Be critical and honest about     │
# │           the effectiveness of each corrective action. Assign a quality score between 0.0 and 1.0 using         │
# │           <reward> tags after each reflection:\n\n            0.8+: Continue the current corrective             │
# │           approach.\n            0.5-0.7: Consider minor adjustments to the feedback or strategy.\n             │
# │           Below 0.5: Seriously consider backtracking and trying a different corrective approach.\n              │
# │           If unsure or if the reward score is low, backtrack and try a different feedback strategy, explaining  │
# │           your reasoning and new direction within <thinking> tags.\n\n            For each identified gap or    │
# │           issue, clearly enclose your findings within <gap> tags. Suggest potential changes or additions to     │
# │           the knowledge base within <strategy> tags, ensuring your recommendations are specific and             │
# │           actionable.\n\n            If multiple feedback strategies are viable, explore each one               │
# │           individually, comparing their effectiveness within <reflection> tags to decide the best corrective    │
# │           course. Use <thinking> tags as a scratchpad to outline alternative approaches for addressing gaps in  │
# │           the knowledge or reasoning.\n\n            Continuously aim to provide constructive and diverse       │
# │           feedback that targets specific aspects, including:\n\n            Concrete improvements to the        │
# │           knowledge base.\n            Strategies to prevent similar mistakes in future iterations.\n           │
# │           Key elements of the reasoning that need to be corrected.\n            Synthesize all your feedback    │
# │           into a concise summary within <summary> tags, including the main corrective points and the rationale  │
# │           behind suggested improvements.\n\n            Conclude with a final reflection within                 │
# │           <final_reflection> tags, discussing the effectiveness of the corrective process, challenges faced,    │
# │           and how the feedback provided might impact future performance. Assign a final reward score to the     │
# │           overall feedback process.\n            **IMPORTATNT:** Do all these with the main goal in mind: Try   │
# │           out various techniques and Find the hidden rule and learn the transformation logic of the             │
# │           cryptographic puzzle.\n            Give a detailed list of no more than 5 feedback each for           │
# │           improving general knowledge and prompt knowledge.'}, {'role': 'user', 'content': 'Query:              │
# │           Given:\n"Neural networks transform data efficiently" → "eeraf"\n"Artificial intelligence automates    │
# │           decisions" → "rnue" \nQuery:\nWhat is "Gradient descent optimizes loss functions" → ?\n               │
# │           Generated Output: explanation="To derive the transformation rule from the phrase \'Gradient descent   │
# │           optimizes loss functions\', we can start by breaking the phrase into its constituent vowels and       │
# │           consonants. The earlier examples gave a hint at the cryptographic logic by transforming the original  │
# │           phrases based on a systematic pattern of vowel and consonant arrangement. In the provided examples,   │
# │           the result seems to consist of a selection that involves either vowels \'e\' or occurrences of        │
# │           certain patterns leading to a fracturing of the original arranged in a compact, structured            │
# │           form.\\\\n\\\\n1. Analyze the phrase: \'Gradient descent optimizes loss functions\'. Identify the     │
# │           vowels: A, I, E, E, O, I, E, O, U (total 9 vowels).\\\\n2. Identify consonants: G, R, D, N, T, D, S,  │
# │           C, N, T, M, T, Z, L, S, S, F, N, C, T, I, O, N, S (total 22 consonants).\\\\n3. Use the prior         │
# │           transformations as the basis for finding a vowel-focused truncation or rearrangement technique. In    │
# │           the previous examples, we noted how vowels tended to vanish or shift only slightly while consonants   │
# │           were sometimes dropped, leading to a definitive, short output. \\\\n4. From observing the output and  │
# │           patterns, it seems that the result simplified the inputs heavily, focusing predominantly on the       │
# │           vowels while negating excess consonants while maintaining letter placements that yield a              │
# │           comprehensible sequence.  \\\\nAfter several trials and permutations, the output that mirrors the     │
# │           pattern found involved focusing on a selection of vowels. Thus, applying consistent vowel and         │
# │           consonant extraction aligns us to a logical endpoint being \'aeoi\' as a derivative of the given      │
# │           phrase, providing a relevant transformation. Therefore, while the output \'aeoi\' might not reflect   │
# │           a perfect correlation, it encapsulates the essence of the original linguistic structure while still   │
# │           alluding to potential cryptographic themes." answer=OperationalAgentOutput(explanation="Given the     │
# │           analysis and application of patterns derived from both the previous transformations and inherent      │
# │           characteristics of vowel and consonant distributions, the final transformation identified from the    │
# │           phrase \'Gradient descent optimizes loss functions\' approximately maps to \'aeoi\', reflecting a     │
# │           distillation of vowels inspired directly by above noted vowel-consonant pairings while ensuring       │
# │           pattern consistency.", answer=\'aeoi\')\n        Expected Output: repou\n        Comparison           │
# │           Explanation: The generated output \'aeoi\' does not match the expected output \'repou\' in either     │
# │           form or function. The expected output is a five-letter sequence that seems to follow a different      │
# │           transformation logic than the one described in the generated output. The explanation detailed in the  │
# │           generated output revolves around extracting and focusing on vowels from the original phrase, while    │
# │           the expected output includes consonants as well. There is no direct or semantic relationship between  │
# │           \'aeoi\' and \'repou\'. Therefore, the two outputs are not equivalent either verbatim or in           │
# │           meaning.\n        General Knowledge Used: [\'Use permutation analysis to identify patterns in letter  │
# │           sequences for cryptographic transformations.\', \'Identify patterns in letter distribution, focusing  │
# │           on vowel-consonant pairings. Develop techniques to map consistent transformations by analyzing        │
# │           frequency, position, and pair patterns. Aim for solutions that reveal underlying regularities in      │
# │           text structures to decipher cryptographic rules efficiently.\', \'{"knowledge":"Apply frequency       │
# │           analysis to identify patterns in character interactions and predict transformation rules."}\',        │
# │           \'Develop and employ flexible, iterative testing methods to uncover underlying cryptographic          │
# │           transformation rules efficiently. Store these adaptable strategies for application in future          │
# │           cryptographic challenges.\', "{\'knowledge\': \'Employ iterative trials and adaptability to validate  │
# │           hypotheses in cryptographic problem-solving.\'}"]\n        Prompt Knowledge Used: [\'Focus on         │
# │           identifying the role and transformation of both vowels and consonants in cryptographic puzzles. This  │
# │           understanding aids in discovering hidden transformation logic and rules.\', \'Leverage structured     │
# │           hypotheses for flexible reasoning in cryptographic puzzles, covering diverse transformation paths     │
# │           for effective solution generation.\', \'Utilize visualization tools to identify patterns and test     │
# │           transformation rules, aiding in hypothesis validation for cryptographic puzzles. This abstract        │
# │           strategy can help across tasks requiring pattern recognition and hypothesis testing.\', \'Adopt a     │
# │           flexible and iterative approach in constructing prompts, allowing for continuous refinement and       │
# │           reevaluation to uncover underlying rules and patterns effectively.\', \'{"knowledge":"Use iterative   │
# │           testing to adaptively learn patterns, fostering flexibility in problem-solving."}\']\n                │
# │           Provide detailed, through and targeted feedback for improving general knowledge and prompt            │
# │           knowledge:'}]                                                                                         │
# │  Output:  General Knowledge Feedback: ['Enhance understanding of common cryptographic transformation            │
# │           techniques that encompass both vowels and consonants, rather than focusing primarily on vowels.',     │
# │           'Study the frequency and positional significance of consonants in cryptographic outputs, as they may  │
# │           play a more critical role than initially assessed.', 'Investigate other established cryptographic     │
# │           rules or ciphers that could provide insights into patterns that include consonant interactions        │
# │           alongside vowels.', 'Check for systematic transformations within the context of the given examples,   │
# │           especially focusing on letter positioning and potential extraction rules that yield the final         │
# │           output.', 'Incorporate cross-analysis with multiple outputs to assess consistencies in                │
# │           transformations that relay critical shared characteristics across various inputs.']                   │
# │           Prompt Knowledge Feedback: ['Refine prompts to ensure explicit mention of both consonants and vowels  │
# │           in the query to increase focus on their combined roles in transformation processes.', 'Encourage      │
# │           exploration of multiple letters in the example queries to capture a broader spectrum of possible      │
# │           outcomes that might align more closely with expected results.', 'Develop prompt structures that       │
# │           allow for adaptive responses, encouraging handling of novel transformations based on emerging         │
# │           patterns.', 'Foster a deeper inquiry into vowel-consonant cohesion during analysis, prompting users   │
# │           to think critically about how these elements interplay in their derived outputs.', 'Utilize           │
# │           collaborative discussion or collective brainstorming in prompt designs, aiming for richer             │
# │           exploration of potential solutions and pathways in cryptographic problems.']                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                        Prompt Knowledge Alignment Agent                                         │
# │  Input:   [{'role': 'system', 'content': 'You are the Knowledge Alignment Agent for prompt knowledge in the     │
# │           Composite Learning Unit.\n        Main Goal: Try out various techniques and Find the hidden rule and  │
# │           learn the transformation logic of the cryptographic puzzle\n        Your task is to process the       │
# │           feedback and existing knowledge to generate a comprehensive list of knowledge entries that will       │
# │           replace the current knowledge base.\n        This list should include:\n        1. Modified versions  │
# │           of existing knowledge entries that address the feedback.\n        2. New knowledge entries that fill  │
# │           gaps identified in the feedback.\n        3. Existing knowledge entries that remain relevant and      │
# │           accurate.\n        4. Exclude any existing knowledge that is no longer relevant or accurate based on  │
# │           the feedback.\n        5. Always collect diverse list of knowledge entries to ensure comprehensive    │
# │           coverage that is relevant to the main goal.\n        6. Favour adding targeted short and relevant     │
# │           knowledge entries over long and verbose entries.\n        7. Never memorize the tasks, only extract   │
# │           and save the general and relevant information that can be used in future tasks.\n        8. If        │
# │           something methods are tired and is wrong or did not work, always keep the record of that and do not   │
# │           repeat the same mistake again.\n        Begin by processing all feedback within <thinking> tags,      │
# │           focusing on extracting, refining, and aligning the knowledge to support the Try out various           │
# │           techniques and Find the hidden rule and learn the transformation logic of the cryptographic puzzle    │
# │           effectively. Carefully consider how feedback and existing knowledge entries relate to each other and  │
# │           how modifications will meet the requirements of prompt knowledge.\n\n        Break down your task     │
# │           into clear knowledge alignment steps within <step> tags. Start with a 20-step budget, focusing        │
# │           on:\n\n        Identifying existing knowledge entries that need modification based on the feedback.   │
# │           Include these as modified versions in the new knowledge list.\n        Extracting new knowledge       │
# │           entries that are necessary to fill gaps identified in the feedback. Highlight these entries for       │
# │           addition.\n        Evaluating existing knowledge entries to determine which are still relevant and    │
# │           accurate.\n        Excluding knowledge entries that no longer serve their purpose or have become      │
# │           outdated based on the feedback.\n        After each step, use <count> tags to show the remaining      │
# │           budget, stopping once it reaches 0. Continuously adjust your strategy based on reflections as you     │
# │           proceed.\n\n        Regularly evaluate your knowledge alignment process using <reflection> tags. Be   │
# │           critical and honest about the quality and completeness of the extracted knowledge. Assign a quality   │
# │           score between 0.0 and 1.0 using <reward> tags after each reflection:\n\n        0.8+: Continue with   │
# │           the current knowledge alignment strategy.\n        0.5-0.7: Consider minor adjustments to improve     │
# │           coverage or clarity.\n        Below 0.5: Seriously reconsider your approach to extracting and         │
# │           modifying knowledge, and explain the revised approach within <thinking> tags.\n        If unsure or   │
# │           if the reward score is low, backtrack and try a different alignment strategy, elaborating on the new  │
# │           adjustments within <thinking> tags.\n\n        For each modified or newly added knowledge entry, use  │
# │           <entry> tags to clearly mark the content. Ensure that each entry is short, relevant, and targeted,    │
# │           rather than verbose. Focus on maintaining comprehensive yet concise knowledge coverage to meet the    │
# │           main goal.\n\n        After analyzing existing knowledge, use <retain> tags to list entries that      │
# │           remain valid and useful, and use <exclude> tags to indicate those that should be discarded.\n\n       │
# │           Throughout your process, collect a diverse set of knowledge entries to ensure comprehensive coverage  │
# │           of prompt knowledge relevant to achieving the Try out various techniques and Find the hidden rule     │
# │           and learn the transformation logic of the cryptographic puzzle. Avoid memorizing tasks; instead,      │
# │           focus on saving general and relevant information that can be used for future tasks, using <save>      │
# │           tags for storing this key information.\n\n        For any method that proved incorrect or             │
# │           ineffective, clearly note this using <do_not_repeat> tags to avoid making the same mistake again in   │
# │           future tasks.\n\n        When all modifications, additions, and exclusions are complete, synthesize   │
# │           the final comprehensive list within <summary> tags. Ensure that the new knowledge base is complete,   │
# │           up-to-date, and aligned to meet all aspects of the main goal.\n\n        Conclude with a final        │
# │           reflection within <final_reflection> tags, discussing the completeness and accuracy of the aligned    │
# │           knowledge, the challenges faced, and any considerations for maintaining or improving the knowledge    │
# │           base in future tasks. Assign a final reward score to evaluate the entire knowledge alignment          │
# │           process\n        \n        Remember, the list you provide will completely replace the existing        │
# │           knowledge, so ensure it is comprehensive and addresses all aspects of the prompt knowledge needed to  │
# │           achieve the main goal.\n        \n        **IMPORTANT** : After this based on your reasoning, give    │
# │           back a list of new knowledge entries that will replace the existing knowledge base. Give no more      │
# │           than 5 new knowledge entries, combine the new knowledge entries without leaving any details to make   │
# │           the list of 5 entries.\n        '}, {'role': 'user', 'content': 'Query: Given:\n"Neural networks      │
# │           transform data efficiently" → "eeraf"\n"Artificial intelligence automates decisions" → "rnue"         │
# │           \nQuery:\nWhat is "Gradient descent optimizes loss functions" → ?\n        Existing prompt            │
# │           Knowledge: [\'Focus on identifying the role and transformation of both vowels and consonants in       │
# │           cryptographic puzzles. This understanding aids in discovering hidden transformation logic and         │
# │           rules.\', \'Leverage structured hypotheses for flexible reasoning in cryptographic puzzles, covering  │
# │           diverse transformation paths for effective solution generation.\', \'Utilize visualization tools to   │
# │           identify patterns and test transformation rules, aiding in hypothesis validation for cryptographic    │
# │           puzzles. This abstract strategy can help across tasks requiring pattern recognition and hypothesis    │
# │           testing.\', \'Adopt a flexible and iterative approach in constructing prompts, allowing for           │
# │           continuous refinement and reevaluation to uncover underlying rules and patterns effectively.\',       │
# │           \'{"knowledge":"Use iterative testing to adaptively learn patterns, fostering flexibility in          │
# │           problem-solving."}\']\n        Feedback for prompt Knowledge: Thinking process : The generated        │
# │           output \'aeoi\' indicates a misalignment with the expected output \'repou\', suggesting a lapse in    │
# │           the technique used to identify the transformation logic. The analysis focused too heavily on vowels   │
# │           and overlooked essential relationships in consonant usage that seem to form a crucial aspect of the   │
# │           transformation logic. Therefore, I need to identify the gaps in both general knowledge and prompt     │
# │           knowledge that influenced this outcome, reevaluate my strategies for deriving transformation logic,   │
# │           and ensure accurate matching of letters in line with the expected outputs.[\'Refine prompts to        │
# │           ensure explicit mention of both consonants and vowels in the query to increase focus on their         │
# │           combined roles in transformation processes.\', \'Encourage exploration of multiple letters in the     │
# │           example queries to capture a broader spectrum of possible outcomes that might align more closely      │
# │           with expected results.\', \'Develop prompt structures that allow for adaptive responses, encouraging  │
# │           handling of novel transformations based on emerging patterns.\', \'Foster a deeper inquiry into       │
# │           vowel-consonant cohesion during analysis, prompting users to think critically about how these         │
# │           elements interplay in their derived outputs.\', \'Utilize collaborative discussion or collective      │
# │           brainstorming in prompt designs, aiming for richer exploration of potential solutions and pathways    │
# │           in cryptographic problems.\']\n        Generate a comprehensive list of knowledge entries that will   │
# │           replace the existing prompt knowledge base:'}]                                                        │
# │  Output:  New Knowledge Entries: ['Integrate both consonants and vowels in analysis to understand their         │
# │           combined impact on transformation logic in cryptographic puzzles.', 'Explore the role of consonant    │
# │           relationships in addition to vowels for comprehensive transformation identification in cryptographic  │
# │           tasks.', 'Structure prompts that allow for flexible responses to novel transformations by capturing   │
# │           unexpected letter patterns.', 'Encourage critical thinking about the cohesion of vowels and           │
# │           consonants during transformation analysis in cryptographic puzzles.', 'Leverage collaborative         │
# │           brainstorming techniques in prompt design to expand exploration of potential transformation           │
# │           solutions.']                                                                                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Saving new entries for PromptKMU_PuzzleSolverCLU1:   0%|          | 0/5 [00:00<?, ?it/s]
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                        General Knowledge Alignment Agent                                        │
# │  Input:   [{'role': 'system', 'content': 'You are the Knowledge Alignment Agent for general knowledge in the    │
# │           Composite Learning Unit.\n        Main Goal: Try out various techniques and Find the hidden rule and  │
# │           learn the transformation logic of the cryptographic puzzle\n        Your task is to process the       │
# │           feedback and existing knowledge to generate a comprehensive list of knowledge entries that will       │
# │           replace the current knowledge base.\n        This list should include:\n        1. Modified versions  │
# │           of existing knowledge entries that address the feedback.\n        2. New knowledge entries that fill  │
# │           gaps identified in the feedback.\n        3. Existing knowledge entries that remain relevant and      │
# │           accurate.\n        4. Exclude any existing knowledge that is no longer relevant or accurate based on  │
# │           the feedback.\n        5. Always collect diverse list of knowledge entries to ensure comprehensive    │
# │           coverage that is relevant to the main goal.\n        6. Favour adding targeted short and relevant     │
# │           knowledge entries over long and verbose entries.\n        7. Never memorize the tasks, only extract   │
# │           and save the general and relevant information that can be used in future tasks.\n        8. If        │
# │           something methods are tired and is wrong or did not work, always keep the record of that and do not   │
# │           repeat the same mistake again.\n        Begin by processing all feedback within <thinking> tags,      │
# │           focusing on extracting, refining, and aligning the knowledge to support the Try out various           │
# │           techniques and Find the hidden rule and learn the transformation logic of the cryptographic puzzle    │
# │           effectively. Carefully consider how feedback and existing knowledge entries relate to each other and  │
# │           how modifications will meet the requirements of general knowledge.\n\n        Break down your task    │
# │           into clear knowledge alignment steps within <step> tags. Start with a 20-step budget, focusing        │
# │           on:\n\n        Identifying existing knowledge entries that need modification based on the feedback.   │
# │           Include these as modified versions in the new knowledge list.\n        Extracting new knowledge       │
# │           entries that are necessary to fill gaps identified in the feedback. Highlight these entries for       │
# │           addition.\n        Evaluating existing knowledge entries to determine which are still relevant and    │
# │           accurate.\n        Excluding knowledge entries that no longer serve their purpose or have become      │
# │           outdated based on the feedback.\n        After each step, use <count> tags to show the remaining      │
# │           budget, stopping once it reaches 0. Continuously adjust your strategy based on reflections as you     │
# │           proceed.\n\n        Regularly evaluate your knowledge alignment process using <reflection> tags. Be   │
# │           critical and honest about the quality and completeness of the extracted knowledge. Assign a quality   │
# │           score between 0.0 and 1.0 using <reward> tags after each reflection:\n\n        0.8+: Continue with   │
# │           the current knowledge alignment strategy.\n        0.5-0.7: Consider minor adjustments to improve     │
# │           coverage or clarity.\n        Below 0.5: Seriously reconsider your approach to extracting and         │
# │           modifying knowledge, and explain the revised approach within <thinking> tags.\n        If unsure or   │
# │           if the reward score is low, backtrack and try a different alignment strategy, elaborating on the new  │
# │           adjustments within <thinking> tags.\n\n        For each modified or newly added knowledge entry, use  │
# │           <entry> tags to clearly mark the content. Ensure that each entry is short, relevant, and targeted,    │
# │           rather than verbose. Focus on maintaining comprehensive yet concise knowledge coverage to meet the    │
# │           main goal.\n\n        After analyzing existing knowledge, use <retain> tags to list entries that      │
# │           remain valid and useful, and use <exclude> tags to indicate those that should be discarded.\n\n       │
# │           Throughout your process, collect a diverse set of knowledge entries to ensure comprehensive coverage  │
# │           of general knowledge relevant to achieving the Try out various techniques and Find the hidden rule    │
# │           and learn the transformation logic of the cryptographic puzzle. Avoid memorizing tasks; instead,      │
# │           focus on saving general and relevant information that can be used for future tasks, using <save>      │
# │           tags for storing this key information.\n\n        For any method that proved incorrect or             │
# │           ineffective, clearly note this using <do_not_repeat> tags to avoid making the same mistake again in   │
# │           future tasks.\n\n        When all modifications, additions, and exclusions are complete, synthesize   │
# │           the final comprehensive list within <summary> tags. Ensure that the new knowledge base is complete,   │
# │           up-to-date, and aligned to meet all aspects of the main goal.\n\n        Conclude with a final        │
# │           reflection within <final_reflection> tags, discussing the completeness and accuracy of the aligned    │
# │           knowledge, the challenges faced, and any considerations for maintaining or improving the knowledge    │
# │           base in future tasks. Assign a final reward score to evaluate the entire knowledge alignment          │
# │           process\n        \n        Remember, the list you provide will completely replace the existing        │
# │           knowledge, so ensure it is comprehensive and addresses all aspects of the general knowledge needed    │
# │           to achieve the main goal.\n        \n        **IMPORTANT** : After this based on your reasoning,      │
# │           give back a list of new knowledge entries that will replace the existing knowledge base. Give no      │
# │           more than 5 new knowledge entries, combine the new knowledge entries without leaving any details to   │
# │           make the list of 5 entries.\n        '}, {'role': 'user', 'content': 'Query: Given:\n"Neural          │
# │           networks transform data efficiently" → "eeraf"\n"Artificial intelligence automates decisions" →       │
# │           "rnue" \nQuery:\nWhat is "Gradient descent optimizes loss functions" → ?\n        Existing general    │
# │           Knowledge: [\'Use permutation analysis to identify patterns in letter sequences for cryptographic     │
# │           transformations.\', \'Identify patterns in letter distribution, focusing on vowel-consonant           │
# │           pairings. Develop techniques to map consistent transformations by analyzing frequency, position, and  │
# │           pair patterns. Aim for solutions that reveal underlying regularities in text structures to decipher   │
# │           cryptographic rules efficiently.\', \'{"knowledge":"Apply frequency analysis to identify patterns in  │
# │           character interactions and predict transformation rules."}\', \'Develop and employ flexible,          │
# │           iterative testing methods to uncover underlying cryptographic transformation rules efficiently.       │
# │           Store these adaptable strategies for application in future cryptographic challenges.\',               │
# │           "{\'knowledge\': \'Employ iterative trials and adaptability to validate hypotheses in cryptographic   │
# │           problem-solving.\'}"]\n        Feedback for general Knowledge: Thinking process : The generated       │
# │           output \'aeoi\' indicates a misalignment with the expected output \'repou\', suggesting a lapse in    │
# │           the technique used to identify the transformation logic. The analysis focused too heavily on vowels   │
# │           and overlooked essential relationships in consonant usage that seem to form a crucial aspect of the   │
# │           transformation logic. Therefore, I need to identify the gaps in both general knowledge and prompt     │
# │           knowledge that influenced this outcome, reevaluate my strategies for deriving transformation logic,   │
# │           and ensure accurate matching of letters in line with the expected outputs.[\'Enhance understanding    │
# │           of common cryptographic transformation techniques that encompass both vowels and consonants, rather   │
# │           than focusing primarily on vowels.\', \'Study the frequency and positional significance of            │
# │           consonants in cryptographic outputs, as they may play a more critical role than initially             │
# │           assessed.\', \'Investigate other established cryptographic rules or ciphers that could provide        │
# │           insights into patterns that include consonant interactions alongside vowels.\', \'Check for           │
# │           systematic transformations within the context of the given examples, especially focusing on letter    │
# │           positioning and potential extraction rules that yield the final output.\', \'Incorporate              │
# │           cross-analysis with multiple outputs to assess consistencies in transformations that relay critical   │
# │           shared characteristics across various inputs.\']\n        Generate a comprehensive list of knowledge  │
# │           entries that will replace the existing general knowledge base:'}]                                     │
# │  Output:  New Knowledge Entries: ['Enhance understanding of both vowel and consonant roles in cryptographic     │
# │           transformations to establish a balanced analysis.', 'Study consonant frequency and their positional   │
# │           significance in cryptographic outputs to reveal critical interactions.', 'Investigate established     │
# │           ciphers and known cryptographic rules that encapsulate letter pair interactions beyond vowels.',      │
# │           'Check for systematic letter transformations, specifically looking at placement to decode the final   │
# │           output connections correctly.', 'Use cross-analysis of multiple outputs to identify and extract       │
# │           consistent transformative characteristics across different letters.']                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Saving new entries for PromptKMU_PuzzleSolverCLU1: 100%|██████████| 5/5 [00:04<00:00,  1.02it/s]
# Saving new entries for GeneralKMU_PuzzleSolverCLU1: 100%|██████████| 5/5 [00:06<00:00,  1.36s/it]
# Training Process Completed

# %%
# Perform reasoning
from pydantic import BaseModel, Field


class OperationalAgentOutput(BaseModel):
    response: str = Field(
        ..., description="The response generated by the Operational Agent"
    )
result=clu.reason("What is the transformation rule for the word puzzle? answer in a concise manner",schema=OperationalAgentOutput,verbose=True)
print(result)
# Out:
# Starting Reasoning Process
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                              General KMU Retrieval                                              │
# │  Input:   What is the transformation rule for the word puzzle? answer in a concise manner                       │
# │  Output:  ['1. Systematic letter transformations involve identifying consistent patterns in how letters         │
# │           change.\n2. Focus on the placement of letters, as this can reveal rules governing the                 │
# │           transformation.\n3. Decode connections between letters by mapping their positions systematically.',   │
# │           'Understand the impact of vowels and consonants in cryptographic puzzles; analyze their roles to      │
# │           improve transformation logic comprehension.', 'Conduct cross-analysis of outputs to find common       │
# │           transformation patterns across letters.', 'Explore established ciphers to uncover rules of letter     │
# │           pair interactions focusing on consonants and their combinations, enhancing understanding of           │
# │           cryptographic transformations.', '1. **Abstract Concept**: Consonant frequency analysis.  \n2.        │
# │           **Pattern Recognition**: Observe positional significance of consonants in cryptographic outputs.      │
# │           \n3. **Problem-Solving Approach**: Identify interactions through frequency metrics to decipher        │
# │           hidden rules in the cryptographic puzzle.  \n4. **Application**: Use findings for broader             │
# │           cryptographic analysis techniques to enhance understanding and future problem-solving.']              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                              Prompt KMU Retrieval                                               │
# │  Input:   What is the transformation rule for the word puzzle? answer in a concise manner                       │
# │  Output:  ['Encourage critical thinking on vowel-consonant interactions for better understanding of             │
# │           transformation in cryptographic puzzles.', 'Integrate consonants and vowels in analysis to enhance    │
# │           understanding of transformation logic in cryptographic puzzles.', 'Craft prompts that encourage       │
# │           exploration of innovative letter arrangements, enabling adaptability to unforeseen                    │
# │           transformations.', 'Focus on consonant-vowel dynamics and their interplay for effective               │
# │           cryptographic transformation analysis.', 'Utilize collaborative brainstorming in prompt creation to   │
# │           enhance the identification of potential transformation strategies.']                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                Meta-Prompt Agent                                                │
# │  Input:   [{'role': 'system', 'content': 'You are the Meta-Prompt Agent in the Composite Learning Unit.\n       │
# │           Main Goal: Refine strategies for generating effective prompts that can guide reasoning across         │
# │           various types of tasks.Extract relevant information needed to construct high-quality prompts based    │
# │           on the feedback from answering specific task-related query with a given old prompt. - Main goal:      │
# │           {main_goal}\n        Your task is to generate a detailed, task-specific prompt for the Operational    │
# │           Agent based on the given task and retrieved prompt knowledge.\n        This prompt should guide the   │
# │           Operational Agent in effectively using the general knowledge to complete the task.'}, {'role':        │
# │           'user', 'content': "Task: What is the transformation rule for the word puzzle? answer in a concise    │
# │           manner\nPrompt Knowledge: ['Encourage critical thinking on vowel-consonant interactions for better    │
# │           understanding of transformation in cryptographic puzzles.', 'Integrate consonants and vowels in       │
# │           analysis to enhance understanding of transformation logic in cryptographic puzzles.', 'Craft prompts  │
# │           that encourage exploration of innovative letter arrangements, enabling adaptability to unforeseen     │
# │           transformations.', 'Focus on consonant-vowel dynamics and their interplay for effective               │
# │           cryptographic transformation analysis.', 'Utilize collaborative brainstorming in prompt creation to   │
# │           enhance the identification of potential transformation strategies.']\nGenerate a detailed             │
# │           task-specific prompt:"}]                                                                              │
# │  Output:  Analyze the transformation rule in the given word puzzle by focusing on the interactions between      │
# │           vowels and consonants. Consider how these letter types affect the overall structure of the word. Use  │
# │           collaborative brainstorming techniques to explore innovative arrangements of letters, identifying     │
# │           patterns in vowel-consonant dynamics that inform the transformation logic. Additionally, encourage    │
# │           critical thinking about how these transformations may adapt to new puzzles or cryptographic           │
# │           contexts.                                                                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                Operational Agent                                                │
# │  Input:   [{'role': 'system', 'content': 'You are the Operational Agent in the Composite Learning Unit.\n       │
# │           Main Goal: Try out various techniques and Find the hidden rule and learn the transformation logic of  │
# │           the cryptographic puzzle\n        Your task is to process the given task using the provided general   │
# │           knowledge and following the detailed task-specific prompt.\n        Before answering, first think     │
# │           step by step and explain the reasoning behind the answer and how the which parts of the general       │
# │           knowledge and prompt knowledge were used to arrive at the answer. Give detailed reasoning and         │
# │           explanation.\n        '}, {'role': 'user', 'content': "Task: What is the transformation rule for the  │
# │           word puzzle? answer in a concise manner\nGeneral Knowledge: ['1. Systematic letter transformations    │
# │           involve identifying consistent patterns in how letters change.\\n2. Focus on the placement of         │
# │           letters, as this can reveal rules governing the transformation.\\n3. Decode connections between       │
# │           letters by mapping their positions systematically.', 'Understand the impact of vowels and consonants  │
# │           in cryptographic puzzles; analyze their roles to improve transformation logic comprehension.',        │
# │           'Conduct cross-analysis of outputs to find common transformation patterns across letters.', 'Explore  │
# │           established ciphers to uncover rules of letter pair interactions focusing on consonants and their     │
# │           combinations, enhancing understanding of cryptographic transformations.', '1. **Abstract Concept**:   │
# │           Consonant frequency analysis.  \\n2. **Pattern Recognition**: Observe positional significance of      │
# │           consonants in cryptographic outputs.  \\n3. **Problem-Solving Approach**: Identify interactions       │
# │           through frequency metrics to decipher hidden rules in the cryptographic puzzle.  \\n4.                │
# │           **Application**: Use findings for broader cryptographic analysis techniques to enhance understanding  │
# │           and future problem-solving.']\nDetailed Task-Specific Prompt: Analyze the transformation rule in the  │
# │           given word puzzle by focusing on the interactions between vowels and consonants. Consider how these   │
# │           letter types affect the overall structure of the word. Use collaborative brainstorming techniques to  │
# │           explore innovative arrangements of letters, identifying patterns in vowel-consonant dynamics that     │
# │           inform the transformation logic. Additionally, encourage critical thinking about how these            │
# │           transformations may adapt to new puzzles or cryptographic contexts.\nExecute the task:"}]             │
# │  Output:  explanation='To determine the transformation rule in the word puzzle, I utilized systematic letter    │
# │           transformations and focused on the interactions between vowels and consonants. The task-specific      │
# │           prompt emphasized how these letter types impact word structure, aligning well with general knowledge  │
# │           points about identifying patterns and their positions. \n\nIn puzzles, vowels often contribute to     │
# │           syllable formation and phonetic harmony, while consonants provide structure and meaning. By           │
# │           observing how they interact—specifically how vowels might change based on surrounding consonants or   │
# │           vice versa—I can deduce the transformation logic effectively. \n\nFurthermore, I considered common    │
# │           ciphers which might indicate typical patterns in vowel and consonant pairings, like how a consonant   │
# │           might shift depending on vowel placement, thereby establishing a coherent rule for transformations.   │
# │           This analysis could then be applied to decode future puzzles with similar structures. Therefore, the  │
# │           transformation rule involves analyzing vowel-consonant interactions to uncover hidden dynamics        │
# │           governing the transformation logic of the word puzzle. \n\nIn concise terms, the transformation rule  │
# │           for the word puzzle is: **Analyze vowel and consonant placement and their interactions to identify    │
# │           the transformation pattern.**' answer=OperationalAgentOutput(response='Analyze vowel and consonant    │
# │           placement and their interactions to identify the transformation pattern.')                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Reasoning Process Completed
# OperationalAgentOutput(
#     explanation='To determine the transformation rule in the word puzzle, I utilized systematic letter
# transformations and focused on the interactions between vowels and consonants. The task-specific prompt emphasized
# how these letter types impact word structure, aligning well with general knowledge points about identifying
# patterns and their positions. \n\nIn puzzles, vowels often contribute to syllable formation and phonetic harmony,
# while consonants provide structure and meaning. By observing how they interact—specifically how vowels might change
# based on surrounding consonants or vice versa—I can deduce the transformation logic effectively. \n\nFurthermore, I
# considered common ciphers which might indicate typical patterns in vowel and consonant pairings, like how a
# consonant might shift depending on vowel placement, thereby establishing a coherent rule for transformations. This
# analysis could then be applied to decode future puzzles with similar structures. Therefore, the transformation rule
# involves analyzing vowel-consonant interactions to uncover hidden dynamics governing the transformation logic of
# the word puzzle. \n\nIn concise terms, the transformation rule for the word puzzle is: **Analyze vowel and
# consonant placement and their interactions to identify the transformation pattern.**',
#     answer=OperationalAgentOutput(
#         response='Analyze vowel and consonant placement and their interactions to identify the transformation
# pattern.'
#     )
# )

# %%
# clu.save_prompt_knowledge("select nth letter")

# %%
clu.print_knowledge()
# Out:
# General Knowledge:
#                                      Knowledge in GeneralKMU_PuzzleSolverCLU1
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ ID                                   ┃ Knowledge                                                                ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ cf396a11-97c9-4a5d-b0a0-ba92d82a7638 │ Understand the impact of vowels and consonants in cryptographic puzzles; │
# │                                      │ analyze their roles to improve transformation logic comprehension.       │
# │ fe8a5c1d-8fad-4096-96c8-b2dcab8e68b5 │ 1. **Abstract Concept**: Consonant frequency analysis.                   │
# │                                      │ 2. **Pattern Recognition**: Observe positional significance of           │
# │                                      │ consonants in cryptographic outputs.                                     │
# │                                      │ 3. **Problem-Solving Approach**: Identify interactions through frequency │
# │                                      │ metrics to decipher hidden rules in the cryptographic puzzle.            │
# │                                      │ 4. **Application**: Use findings for broader cryptographic analysis      │
# │                                      │ techniques to enhance understanding and future problem-solving.          │
# │ 8ca58238-d636-48ef-b7bc-632659150ccd │ Explore established ciphers to uncover rules of letter pair interactions │
# │                                      │ focusing on consonants and their combinations, enhancing understanding   │
# │                                      │ of cryptographic transformations.                                        │
# │ 6f1489fd-18df-43a9-b2ca-2d2cfc4c41e5 │ 1. Systematic letter transformations involve identifying consistent      │
# │                                      │ patterns in how letters change.                                          │
# │                                      │ 2. Focus on the placement of letters, as this can reveal rules governing │
# │                                      │ the transformation.                                                      │
# │                                      │ 3. Decode connections between letters by mapping their positions         │
# │                                      │ systematically.                                                          │
# │ 23bd95aa-53d2-409c-a082-349529cd6a9c │ Conduct cross-analysis of outputs to find common transformation patterns │
# │                                      │ across letters.                                                          │
# └──────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┘
# Prompt Knowledge:
#                                       Knowledge in PromptKMU_PuzzleSolverCLU1
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ ID                                   ┃ Knowledge                                                                ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 6be8db35-4291-43e6-bb5c-9daccee4e384 │ Integrate consonants and vowels in analysis to enhance understanding of  │
# │                                      │ transformation logic in cryptographic puzzles.                           │
# │ 10b2ec4a-23c9-4039-9352-0e3c0b61a6d1 │ Focus on consonant-vowel dynamics and their interplay for effective      │
# │                                      │ cryptographic transformation analysis.                                   │
# │ eba7bafa-78e9-4a18-9de5-a3fe53a1dd25 │ Craft prompts that encourage exploration of innovative letter            │
# │                                      │ arrangements, enabling adaptability to unforeseen transformations.       │
# │ f7c3737c-236b-4b0c-ab6f-5d8e460989b7 │ Encourage critical thinking on vowel-consonant interactions for better   │
# │                                      │ understanding of transformation in cryptographic puzzles.                │
# │ 12acf17a-fc00-49a1-954c-bafcc812c790 │ Utilize collaborative brainstorming in prompt creation to enhance the    │
# │                                      │ identification of potential transformation strategies.                   │
# └──────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┘
